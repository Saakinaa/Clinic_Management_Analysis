# %% [markdown]
# <a href="https://colab.research.google.com/github/Saakinaa/Clinic_Management_Analysis/blob/main/MedGen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MedGen**

# %% [markdown]
# ## **Generate Random Data**

# %%
# Import libraries

import json
import os
import random
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %% [markdown]
# ### **Generate Date**

# %%
# Generate random date within range
def random_date(start, end):
    delta = end - start
    int_delta = (delta.days * 24 * 60 * 60) + delta.seconds
    random_second = random.randrange(int_delta)
    return start + timedelta(seconds=random_second)

# %%
#test
random_date(datetime.strptime('1/1/2020 1:30 PM', '%m/%d/%Y %I:%M %p'), datetime.strptime('1/1/2021 4:50 AM', '%m/%d/%Y %I:%M %p'))
# Out:
# datetime.datetime(2020, 3, 13, 5, 56, 11)

# %%
# Format date to YYYY-MM-DD
def format_date(date):
    return date.strftime('%Y-%m-%d')

# format_date(date)

# %% [markdown]
# ### **Generate patient data**
#
# Génère **1000 patients** avec les éléments suivants :
#
# - age, gender, department, treatment, etc.
#
# - admissionDate : date d’admission (aléatoire sur les 90 derniers jours).
#
# - dischargeDate : nulle si le patient est toujours hospitalisé.
#
# - stayDuration : soit la durée réelle, soit la durée depuis l’admission.
#
# - outcome : s'il est sorti, résultat de traitement pondéré (60% rétabli…).
#
# - treatmentCost : calcul basé sur un coût de base (département + traitement).
#
# - insuranceCovered : % aléatoire de couverture (entre 70% et 95% environ).
#
# Le **coût total** du traitement dépend de :
#
# - Le département (coût de base)
#
# - Le type de traitement (ajoute des surcoûts pour chirurgie ou soins intensifs)
#
# - La durée du séjour

# %%
# Generate patient data
def generate_patient_data(days=90):
    patients = []
    now = datetime.now()
    departments = ['Cardiology', 'Neurology', 'Oncology', 'Pediatrics', 'Emergency', 'Surgery']
    treatments = ['Medication', 'Surgery', 'Therapy', 'Observation', 'Intensive Care']
    outcomes = ['Recovered', 'Improved', 'Stable', 'Deteriorated', 'Deceased']
    outcome_weights = [0.6, 0.2, 0.1, 0.07, 0.03]  # Probability weights

    for i in range(1000):
        admission_date = random_date(now - timedelta(days=days), now)
        stay_duration = random.randint(1, 30)
        discharge_date = admission_date + timedelta(days=stay_duration)

        # Determine if patient is still admitted
        is_admitted = discharge_date > now

        department = random.choice(departments)
        treatment = random.choice(treatments)

        # Weighted random outcome selection
        if is_admitted:
            outcome = 'In Treatment'
        else:
            outcome = random.choices(outcomes, weights=outcome_weights)[0]

        # Generate costs based on department and treatment
        base_cost = {
            'Cardiology': 1500,
            'Neurology': 1800,
            'Oncology': 2200,
            'Pediatrics': 1000,
            'Emergency': 2000,
            'Surgery': 3000
        }.get(department, 1200)

        if treatment == 'Surgery':
            base_cost += 5000
        if treatment == 'Intensive Care':
            base_cost += 3000

        treatment_cost = base_cost * (0.8 + random.random() * 0.4) * stay_duration

        patients.append({
            'patientId': f'P{1000 + i}',
            'age': random.randint(1, 95),
            'gender': random.choice(['Male', 'Female']),
            'department': department,
            'admissionDate': format_date(admission_date),
            'dischargeDate': None if is_admitted else format_date(discharge_date),
            'stayDuration': (now - admission_date).days if is_admitted else stay_duration,
            'treatment': treatment,
            'outcome': outcome,
            'treatmentCost': round(treatment_cost),
            'insuranceCovered': round(treatment_cost * (0.7 + random.random() * 0.25)),
            'isAdmitted': is_admitted
        })

    return patients

# %%
patient_data = generate_patient_data()
pd.DataFrame(patient_data)
# Out:
#     patientId  age  gender  department admissionDate dischargeDate  \
# 0       P1000   60    Male     Surgery    2026-01-06    2026-01-21
# 1       P1001   83    Male    Oncology    2026-03-16          None
# 2       P1002   56  Female  Cardiology    2026-01-11    2026-01-14
# 3       P1003   17  Female     Surgery    2026-01-02    2026-01-19
# 4       P1004   15  Female   Neurology    2026-02-12    2026-02-21
# ..        ...  ...     ...         ...           ...           ...
# 995     P1995   68    Male   Neurology    2026-01-13    2026-02-02
# 996     P1996   44    Male     Surgery    2026-01-10    2026-01-27
# 997     P1997    1  Female  Pediatrics    2026-01-04    2026-01-16
# 998     P1998   81    Male     Surgery    2026-02-28          None
# 999     P1999   58  Female   Neurology    2026-02-23          None
#
#      stayDuration       treatment       outcome  treatmentCost  \
# 0              15  Intensive Care      Improved         106344
# 1               0  Intensive Care  In Treatment          98801
# 2               3         Therapy      Improved           3891
# 3              17         Surgery     Recovered         141190
# 4               9  Intensive Care     Recovered          38189
# ..            ...             ...           ...            ...
# 995            20      Medication     Recovered          37028
# 996            17      Medication  Deteriorated          49022
# 997            12         Surgery  Deteriorated          71751
# 998            15      Medication  In Treatment          57510
# 999            20     Observation  In Treatment          46116
#
#      insuranceCovered  isAdmitted
# 0               94618       False
# 1               80721        True
# 2                2760       False
# 3              107068       False
# 4               35411       False
# ..                ...         ...
# 995             34162       False
# 996             41545       False
# 997             56850       False
# 998             45758        True
# 999             41615        True
#
# [1000 rows x 12 columns]

# %% [markdown]
# ### **Generate Staff Data**
#
# Crée **200 membres** du personnel :
#
# - role : Docteur, infirmier, technicien, etc.
#
# - salary : dépend du rôle, du département, et de l’ancienneté (yearsOfService)
#
# - performanceScore : score entre 0.70 et 1.00.
#
# - patientsHandled : uniquement pour les rôles médicaux (doctor, nurse, etc.).
#
# Le salaire est ajusté selon :
#
# - Un coefficient pour les départements comme Chirurgie ou Cardiologie (x1.2)
#
# - Une augmentation de 2% par année d’ancienneté

# %%
# Generate staff data
def generate_staff_data():
    departments = ['Cardiology', 'Neurology', 'Oncology', 'Pediatrics', 'Emergency', 'Surgery', 'Administration']
    roles = ['Doctor', 'Nurse', 'Technician', 'Administrative', 'Support']
    staff = []

    for i in range(200):
        department = random.choice(departments)
        role = random.choice(roles)

        # Base salary by role
        base_salary = {
            'Doctor': 120000,
            'Nurse': 70000,
            'Technician': 60000,
            'Administrative': 50000,
            'Support': 40000
        }.get(role, 45000)

        # Adjust by department
        if department in ['Surgery', 'Cardiology']:
            base_salary *= 1.2

        years_of_service = random.randint(0, 30)
        # Salary increases with years of service
        salary = round(base_salary * (1 + years_of_service * 0.02))

        staff.append({
            'staffId': f'S{1000 + i}',
            'department': department,
            'role': role,
            'yearsOfService': years_of_service,
            'salary': salary,
            'patientsHandled': random.randint(10, 100) if role in ['Doctor', 'Nurse'] else 0,
            'performanceScore': round(random.uniform(70, 100) / 100, 2)
        })

    return staff

# %%
staff_data = generate_staff_data()
pd.DataFrame(staff_data)
# Out:
#     staffId      department            role  yearsOfService  salary  \
# 0     S1000       Emergency      Technician              13   75600
# 1     S1001      Cardiology          Doctor              29  227520
# 2     S1002      Pediatrics          Doctor              20  168000
# 3     S1003         Surgery           Nurse              29  132720
# 4     S1004        Oncology      Technician              11   73200
# ..      ...             ...             ...             ...     ...
# 195   S1195  Administration  Administrative              12   62000
# 196   S1196         Surgery  Administrative               8   69600
# 197   S1197  Administration  Administrative              30   80000
# 198   S1198  Administration           Nurse              18   95200
# 199   S1199        Oncology          Doctor              23  175200
#
#      patientsHandled  performanceScore
# 0                  0              0.79
# 1                 28              0.86
# 2                 47              0.75
# 3                 99              0.86
# 4                  0              0.78
# ..               ...               ...
# 195                0              0.81
# 196                0              0.98
# 197                0              0.88
# 198               94              0.92
# 199               69              0.77
#
# [200 rows x 7 columns]

# %% [markdown]
# ### **Generate Departement Data**
#
# Pour chaque département (**6 au total**) :
#
# - Patients : combien, durée moyenne de séjour, taux de guérison
#
# - Finances : revenu total (somme des coûts de traitement), salaires totaux, coût d’exploitation
#
# - Ressources : lits disponibles, lits occupés (bed utilization), nombre de staff
#
# - Performance médicale : taux de guérison (patients sortis guéris ou améliorés)

# %%
# Generate department performance data
def generate_department_data(patient_data, staff_data):
    departments = ['Cardiology', 'Neurology', 'Oncology', 'Pediatrics', 'Emergency', 'Surgery']
    department_data = []

    for dept in departments:
        dept_patients = [p for p in patient_data if p['department'] == dept]
        dept_staff = [s for s in staff_data if s['department'] == dept]

        total_patients = len(dept_patients)
        if total_patients > 0:
            avg_stay_duration = sum(p['stayDuration'] for p in dept_patients) / total_patients
        else:
            avg_stay_duration = 0

        total_revenue = sum(p['treatmentCost'] for p in dept_patients)
        total_salaries = sum(s['salary'] for s in dept_staff)

        # Calculate recovery rate
        non_admitted = [p for p in dept_patients if not p['isAdmitted']]
        recovered_patients = len([p for p in non_admitted if p['outcome'] in ['Recovered', 'Improved']])
        recovery_rate = recovered_patients / len(non_admitted) if len(non_admitted) > 0 else 0

        # Calculate bed utilization
        beds_available = {
            'Cardiology': 50,
            'Neurology': 40,
            'Oncology': 60,
            'Pediatrics': 45,
            'Emergency': 30,
            'Surgery': 35
        }[dept]

        currently_admitted = len([p for p in dept_patients if p['isAdmitted']])
        bed_utilization = currently_admitted / beds_available

        department_data.append({
            'department': dept,
            'totalPatients': total_patients,
            'avgStayDuration': round(avg_stay_duration, 2),
            'totalRevenue': total_revenue,
            'totalSalaries': total_salaries,
            'operatingCost': total_salaries + random.randint(50000, 200000),  # Add other costs
            'recoveryRate': round(recovery_rate, 2),
            'bedsAvailable': beds_available,
            'currentlyAdmitted': currently_admitted,
            'bedUtilization': round(bed_utilization, 2),
            'staffCount': len(dept_staff),
            'doctorCount': len([s for s in dept_staff if s['role'] == 'Doctor']),
            'nurseCount': len([s for s in dept_staff if s['role'] == 'Nurse'])
        })

    return department_data

# %%
department_data = generate_department_data(patient_data, staff_data)
pd.DataFrame(department_data)
# Out:
#    department  totalPatients  avgStayDuration  totalRevenue  totalSalaries  \
# 0  Cardiology            151            14.15       7493272        3014640
# 1   Neurology            172            13.43       8622894        2658000
# 2    Oncology            160            13.24       9352024        3014600
# 3  Pediatrics            170            13.94       6866343        2785000
# 4   Emergency            156            13.85       8242040        1986200
# 5     Surgery            191            13.46      14540510        3245040
#
#    operatingCost  recoveryRate  bedsAvailable  currentlyAdmitted  \
# 0        3162214          0.88             50                 36
# 1        2842455          0.86             40                 38
# 2        3143117          0.85             60                 33
# 3        2876917          0.82             45                 37
# 4        2163947          0.75             30                 30
# 5        3369961          0.85             35                 29
#
#    bedUtilization  staffCount  doctorCount  nurseCount
# 0            0.72          26            9           5
# 1            0.95          27            8           3
# 2            0.55          33            9           3
# 3            0.82          33            4           8
# 4            1.00          23            4           3
# 5            0.83          30            5           6

# %% [markdown]
# ### **Generate Daily Metrics**
#
# Génère des données aléatoires pour 90 jours :
#
# - newAdmissions, discharges, emergencyVisits, surgeries, revenue, expenses
#
# Cela permet d’**analyser l’activité jour par jour** sous forme de **séries temporelles**.

# %%
# Generate daily metrics for time series
def generate_daily_metrics(days=90):
    daily_metrics = []
    now = datetime.now()

    for i in range(days):
        date = now - timedelta(days=days-i)

        daily_metrics.append({
            'date': format_date(date),
            'newAdmissions': random.randint(5, 25),
            'discharges': random.randint(5, 20),
            'emergencyVisits': random.randint(20, 60),
            'surgeries': random.randint(3, 15),
            'revenue': random.randint(50000, 150000),
            'expenses': random.randint(40000, 120000)
        })

    return daily_metrics

# %%
daily_metrics_data = generate_daily_metrics()
pd.DataFrame(daily_metrics_data)
# Out:
#           date  newAdmissions  discharges  emergencyVisits  surgeries  \
# 0   2025-12-16             11          12               30         10
# 1   2025-12-17             24          17               30         15
# 2   2025-12-18             23          14               20          3
# 3   2025-12-19             23          16               39          6
# 4   2025-12-20             18          11               38          4
# ..         ...            ...         ...              ...        ...
# 85  2026-03-11             20          10               35          9
# 86  2026-03-12             15           9               32         10
# 87  2026-03-13              5          10               25         15
# 88  2026-03-14             17           8               34          6
# 89  2026-03-15             21          17               44         11
#
#     revenue  expenses
# 0     67703     84040
# 1     63411     98132
# 2    108100     58997
# 3     58816     91609
# 4     60234     68298
# ..      ...       ...
# 85    68742     54089
# 86    51478     60647
# 87    94643     52551
# 88    97998     56195
# 89    58676     86236
#
# [90 rows x 7 columns]

# %% [markdown]
# ### **Generate all data (Skip it)**
#
# This part will generate all data and save it to JSON files.
#
# - Appelle les 4 fonctions ci-dessus
#
# - Crée un dossier ./data si nécessaire
#
# - Sauvegarde chaque jeu de données dans un fichier .json
#
#   - patients.json
#
#   - staff.json
#
#   - departments.json
#
#   - daily_metrics.json
#
# - Affiche un résumé du nombre d'enregistrements générés

# %%
# Generate all data and save to JSON files
def generate_all_data():
    patient_data = generate_patient_data()
    staff_data = generate_staff_data()
    department_data = generate_department_data(patient_data, staff_data)
    daily_metrics = generate_daily_metrics()

    # Create data directory if it doesn't exist
    if not os.path.exists('./data'):
        os.makedirs('./data')

    with open('./content/drive/MyDrive/Colab Notebooks/patients.json', 'w') as f:
        json.dump(patient_data, f, indent=2)

    with open('./content/drive/MyDrive/Colab Notebooks/staff.json', 'w') as f:
        json.dump(staff_data, f, indent=2)

    with open('./content/drive/MyDrive/Colab Notebooks/departments.json', 'w') as f:
        json.dump(department_data, f, indent=2)

    with open('./content/drive/MyDrive/Colab Notebooks/daily_metrics.json', 'w') as f:
        json.dump(daily_metrics, f, indent=2)

    print('Generated fictive health structure data:')
    print(f'- {len(patient_data)} patient records')
    print(f'- {len(staff_data)} staff records')
    print(f'- {len(department_data)} department performance records')
    print(f'- {len(daily_metrics)} days of daily metrics')
    print('Data saved to ./data/ directory')

# %%
# Save data on csv format
import os

# Create data directory if it doesn't exist
if not os.path.exists('./content/drive/MyDrive/Colab Notebooks'):
    os.makedirs('./content/drive/MyDrive/Colab Notebooks')

patient = pd.DataFrame(patient_data)
staff = pd.DataFrame(staff_data)
department = pd.DataFrame(department_data)
metrics = pd.DataFrame(daily_metrics_data)

# Patient File
patient.to_csv('patients.csv', index=False)

# Staff File
staff.to_csv('staff.csv', index=False)

# Department File
department.to_csv('departments.csv', index=False)

# Metrics File
metrics.to_csv('daily_metrics.csv', index=False)

# %% [markdown]
# ### **Exécution**
#
# Cela permet d’exécuter le script uniquement lorsqu'il est lancé directement (et non importé comme module).

# %%
if __name__ == "__main__":
    generate_all_data()
# Out:
# Generated fictive health structure data:
# - 1000 patient records
# - 200 staff records
# - 6 department performance records
# - 90 days of daily metrics
# Data saved to ./data/ directory

# %% [markdown]
# ## **Data Pre-processing**

# %% [markdown]
# ### **Load Data**

# %%
# Load Patients data

patient_data = pd.read_csv('patients.csv')

# %%
# Load Staff data

staff_data = pd.read_csv('staff.csv')

# %%
# Load Departments data

department_data = pd.read_csv('departments.csv')

# %%
# Load Daily metrics data

metrics_data = pd.read_csv('daily_metrics.csv')

# %% [markdown]
# ### **Display datasets**

# %%
# Patients Data

patient_data.head()
# Out:
#   patientId  age  gender  department admissionDate dischargeDate  \
# 0     P1000   60    Male     Surgery    2026-01-06    2026-01-21
# 1     P1001   83    Male    Oncology    2026-03-16           NaN
# 2     P1002   56  Female  Cardiology    2026-01-11    2026-01-14
# 3     P1003   17  Female     Surgery    2026-01-02    2026-01-19
# 4     P1004   15  Female   Neurology    2026-02-12    2026-02-21
#
#    stayDuration       treatment       outcome  treatmentCost  \
# 0            15  Intensive Care      Improved         106344
# 1             0  Intensive Care  In Treatment          98801
# 2             3         Therapy      Improved           3891
# 3            17         Surgery     Recovered         141190
# 4             9  Intensive Care     Recovered          38189
#
#    insuranceCovered  isAdmitted
# 0             94618       False
# 1             80721        True
# 2              2760       False
# 3            107068       False
# 4             35411       False

# %%
# Staff Data

staff_data.head()
# Out:
#   staffId  department        role  yearsOfService  salary  patientsHandled  \
# 0   S1000   Emergency  Technician              13   75600                0
# 1   S1001  Cardiology      Doctor              29  227520               28
# 2   S1002  Pediatrics      Doctor              20  168000               47
# 3   S1003     Surgery       Nurse              29  132720               99
# 4   S1004    Oncology  Technician              11   73200                0
#
#    performanceScore
# 0              0.79
# 1              0.86
# 2              0.75
# 3              0.86
# 4              0.78

# %%
# Department Data

department_data.head()
# Out:
#    department  totalPatients  avgStayDuration  totalRevenue  totalSalaries  \
# 0  Cardiology            151            14.15       7493272        3014640
# 1   Neurology            172            13.43       8622894        2658000
# 2    Oncology            160            13.24       9352024        3014600
# 3  Pediatrics            170            13.94       6866343        2785000
# 4   Emergency            156            13.85       8242040        1986200
#
#    operatingCost  recoveryRate  bedsAvailable  currentlyAdmitted  \
# 0        3162214          0.88             50                 36
# 1        2842455          0.86             40                 38
# 2        3143117          0.85             60                 33
# 3        2876917          0.82             45                 37
# 4        2163947          0.75             30                 30
#
#    bedUtilization  staffCount  doctorCount  nurseCount
# 0            0.72          26            9           5
# 1            0.95          27            8           3
# 2            0.55          33            9           3
# 3            0.82          33            4           8
# 4            1.00          23            4           3

# %%
# Daily Metrics Data

metrics_data.head()
# Out:
#          date  newAdmissions  discharges  emergencyVisits  surgeries  revenue  \
# 0  2025-12-16             11          12               30         10    67703
# 1  2025-12-17             24          17               30         15    63411
# 2  2025-12-18             23          14               20          3   108100
# 3  2025-12-19             23          16               39          6    58816
# 4  2025-12-20             18          11               38          4    60234
#
#    expenses
# 0     84040
# 1     98132
# 2     58997
# 3     91609
# 4     68298

# %% [markdown]
# ### **Data Explorer**

# %%
# Data Explorer

def explore_info(data):
  print("\n--- Infos sur le DataFrame ---")
  print("====================================")
  print("     ")
  print("     ")
  data.info()

def describe_data(data):
  print("\n--- Statistiques descriptives ---")
  print("====================================")
  print("     ")
  print("     ")

  print(data.describe(include='all'))

def unique_values(data):
  print("\n--- Valeurs uniques par colonne ---")
  print("====================================")
  print("     ")
  print("     ")
  for col in data.columns:
    print(f"{col} : {data[col].nunique()} valeurs uniques")
    print("---------------------------------------")

# %% [markdown]
# #### **Patient**

# %%
# Informations

explore_info(patient_data)
# Out:
# --- Infos sur le DataFrame ---
# ====================================
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   patientId         1000 non-null   object
#  1   age               1000 non-null   int64
#  2   gender            1000 non-null   object
#  3   department        1000 non-null   object
#  4   admissionDate     1000 non-null   object
#  5   dischargeDate     797 non-null    object
#  6   stayDuration      1000 non-null   int64
#  7   treatment         1000 non-null   object
#  8   outcome           1000 non-null   object
#  9   treatmentCost     1000 non-null   int64
#  10  insuranceCovered  1000 non-null   int64
#  11  isAdmitted        1000 non-null   bool
# dtypes: bool(1), int64(4), object(7)
# memory usage: 87.0+ KB

# %%
# Descriptive Statistics

describe_data(patient_data)
# Out:
# --- Statistiques descriptives ---
# ====================================
#
#
#        patientId          age gender department admissionDate dischargeDate  \
# count       1000  1000.000000   1000       1000          1000           797
# unique      1000          NaN      2          6            91            87
# top        P1999          NaN   Male    Surgery    2026-03-10    2026-02-05
# freq           1          NaN    529        191            19            18
# mean         NaN    48.227000    NaN        NaN           NaN           NaN
# std          NaN    27.115729    NaN        NaN           NaN           NaN
# min          NaN     1.000000    NaN        NaN           NaN           NaN
# 25%          NaN    25.000000    NaN        NaN           NaN           NaN
# 50%          NaN    49.000000    NaN        NaN           NaN           NaN
# 75%          NaN    72.250000    NaN        NaN           NaN           NaN
# max          NaN    95.000000    NaN        NaN           NaN           NaN
#
#         stayDuration   treatment    outcome  treatmentCost  insuranceCovered  \
# count    1000.000000        1000       1000    1000.000000       1000.000000
# unique           NaN           5          6            NaN               NaN
# top              NaN  Medication  Recovered            NaN               NaN
# freq             NaN         216        482            NaN               NaN
# mean       13.664000         NaN        NaN   55117.083000      45226.511000
# std         8.630387         NaN        NaN   49552.262288      40663.674572
# min         0.000000         NaN        NaN     811.000000        575.000000
# 25%         6.000000         NaN        NaN   18722.500000      15212.250000
# 50%        13.000000         NaN        NaN   38024.500000      31551.500000
# 75%        21.000000         NaN        NaN   76242.250000      62055.500000
# max        30.000000         NaN        NaN  264878.000000     237459.000000
#
#        isAdmitted
# count        1000
# unique          2
# top         False
# freq          797
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
# Explore Unique values

unique_values(patient_data)
# Out:
# --- Valeurs uniques par colonne ---
# ====================================
#
#
# patientId : 1000 valeurs uniques
# ---------------------------------------
# age : 95 valeurs uniques
# ---------------------------------------
# gender : 2 valeurs uniques
# ---------------------------------------
# department : 6 valeurs uniques
# ---------------------------------------
# admissionDate : 91 valeurs uniques
# ---------------------------------------
# dischargeDate : 87 valeurs uniques
# ---------------------------------------
# stayDuration : 31 valeurs uniques
# ---------------------------------------
# treatment : 5 valeurs uniques
# ---------------------------------------
# outcome : 6 valeurs uniques
# ---------------------------------------
# treatmentCost : 994 valeurs uniques
# ---------------------------------------
# insuranceCovered : 994 valeurs uniques
# ---------------------------------------
# isAdmitted : 2 valeurs uniques
# ---------------------------------------

# %% [markdown]
# #### **Staff**

# %%
# Informations

explore_info(staff_data)
# Out:
# --- Infos sur le DataFrame ---
# ====================================
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   staffId           200 non-null    object
#  1   department        200 non-null    object
#  2   role              200 non-null    object
#  3   yearsOfService    200 non-null    int64
#  4   salary            200 non-null    int64
#  5   patientsHandled   200 non-null    int64
#  6   performanceScore  200 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 11.1+ KB

# %%
# Descriptive Statistics

describe_data(staff_data)
# Out:
# --- Statistiques descriptives ---
# ====================================
#
#
#        staffId  department            role  yearsOfService         salary  \
# count      200         200             200      200.000000     200.000000
# unique     200           7               5             NaN            NaN
# top      S1000  Pediatrics  Administrative             NaN            NaN
# freq         1          33              51             NaN            NaN
# mean       NaN         NaN             NaN       14.845000   95885.400000
# std        NaN         NaN             NaN        8.665821   43780.118969
# min        NaN         NaN             NaN        0.000000   40000.000000
# 25%        NaN         NaN             NaN        7.000000   64950.000000
# 50%        NaN         NaN             NaN       15.000000   78500.000000
# 75%        NaN         NaN             NaN       22.000000  111240.000000
# max        NaN         NaN             NaN       30.000000  230400.000000
#
#         patientsHandled  performanceScore
# count        200.000000        200.000000
# unique              NaN               NaN
# top                 NaN               NaN
# freq                NaN               NaN
# mean          22.760000          0.859600
# std           32.568018          0.079911
# min            0.000000          0.700000
# 25%            0.000000          0.790000
# 50%            0.000000          0.860000
# 75%           45.000000          0.920000
# max           99.000000          1.000000

# %%
# Explore unique values

unique_values(staff_data)
# Out:
# --- Valeurs uniques par colonne ---
# ====================================
#
#
# staffId : 200 valeurs uniques
# ---------------------------------------
# department : 7 valeurs uniques
# ---------------------------------------
# role : 5 valeurs uniques
# ---------------------------------------
# yearsOfService : 31 valeurs uniques
# ---------------------------------------
# salary : 127 valeurs uniques
# ---------------------------------------
# patientsHandled : 57 valeurs uniques
# ---------------------------------------
# performanceScore : 31 valeurs uniques
# ---------------------------------------

# %% [markdown]
# #### **Departments**

# %%
# Informations

explore_info(department_data)
# Out:
# --- Infos sur le DataFrame ---
# ====================================
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   department         6 non-null      object
#  1   totalPatients      6 non-null      int64
#  2   avgStayDuration    6 non-null      float64
#  3   totalRevenue       6 non-null      int64
#  4   totalSalaries      6 non-null      int64
#  5   operatingCost      6 non-null      int64
#  6   recoveryRate       6 non-null      float64
#  7   bedsAvailable      6 non-null      int64
#  8   currentlyAdmitted  6 non-null      int64
#  9   bedUtilization     6 non-null      float64
#  10  staffCount         6 non-null      int64
#  11  doctorCount        6 non-null      int64
#  12  nurseCount         6 non-null      int64
# dtypes: float64(3), int64(9), object(1)
# memory usage: 756.0+ bytes

# %%
# Descriptive Statistics

describe_data(department_data)
# Out:
# --- Statistiques descriptives ---
# ====================================
#
#
#         department  totalPatients  avgStayDuration  totalRevenue  \
# count            6       6.000000         6.000000  6.000000e+00
# unique           6            NaN              NaN           NaN
# top     Cardiology            NaN              NaN           NaN
# freq             1            NaN              NaN           NaN
# mean           NaN     166.666667        13.678333  9.186180e+06
# std            NaN      14.389811         0.352671  2.762341e+06
# min            NaN     151.000000        13.240000  6.866343e+06
# 25%            NaN     157.000000        13.437500  7.680464e+06
# 50%            NaN     165.000000        13.655000  8.432467e+06
# 75%            NaN     171.500000        13.917500  9.169742e+06
# max            NaN     191.000000        14.150000  1.454051e+07
#
#         totalSalaries  operatingCost  recoveryRate  bedsAvailable  \
# count    6.000000e+00   6.000000e+00      6.000000       6.000000
# unique            NaN            NaN           NaN            NaN
# top               NaN            NaN           NaN            NaN
# freq              NaN            NaN           NaN            NaN
# mean     2.783913e+06   2.926435e+06      0.835000      43.333333
# std      4.407473e+05   4.219362e+05      0.045935      10.801234
# min      1.986200e+06   2.163947e+06      0.750000      30.000000
# 25%      2.689750e+06   2.851070e+06      0.827500      36.250000
# 50%      2.899800e+06   3.010017e+06      0.850000      42.500000
# 75%      3.014630e+06   3.157440e+06      0.857500      48.750000
# max      3.245040e+06   3.369961e+06      0.880000      60.000000
#
#         currentlyAdmitted  bedUtilization  staffCount  doctorCount  nurseCount
# count            6.000000        6.000000    6.000000     6.000000    6.000000
# unique                NaN             NaN         NaN          NaN         NaN
# top                   NaN             NaN         NaN          NaN         NaN
# freq                  NaN             NaN         NaN          NaN         NaN
# mean            33.833333        0.811667   28.666667     6.500000    4.666667
# std              3.763863        0.162409    4.033196     2.428992    2.065591
# min             29.000000        0.550000   23.000000     4.000000    3.000000
# 25%             30.750000        0.745000   26.250000     4.250000    3.000000
# 50%             34.500000        0.825000   28.500000     6.500000    4.000000
# 75%             36.750000        0.920000   32.250000     8.750000    5.750000
# max             38.000000        1.000000   33.000000     9.000000    8.000000

# %%
# Explore unique values

unique_values(department_data)
# Out:
# --- Valeurs uniques par colonne ---
# ====================================
#
#
# department : 6 valeurs uniques
# ---------------------------------------
# totalPatients : 6 valeurs uniques
# ---------------------------------------
# avgStayDuration : 6 valeurs uniques
# ---------------------------------------
# totalRevenue : 6 valeurs uniques
# ---------------------------------------
# totalSalaries : 6 valeurs uniques
# ---------------------------------------
# operatingCost : 6 valeurs uniques
# ---------------------------------------
# recoveryRate : 5 valeurs uniques
# ---------------------------------------
# bedsAvailable : 6 valeurs uniques
# ---------------------------------------
# currentlyAdmitted : 6 valeurs uniques
# ---------------------------------------
# bedUtilization : 6 valeurs uniques
# ---------------------------------------
# staffCount : 5 valeurs uniques
# ---------------------------------------
# doctorCount : 4 valeurs uniques
# ---------------------------------------
# nurseCount : 4 valeurs uniques
# ---------------------------------------

# %% [markdown]
# #### **Daily Metrics**

# %%
# Informations

explore_info(metrics_data)
# Out:
# --- Infos sur le DataFrame ---
# ====================================
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             90 non-null     object
#  1   newAdmissions    90 non-null     int64
#  2   discharges       90 non-null     int64
#  3   emergencyVisits  90 non-null     int64
#  4   surgeries        90 non-null     int64
#  5   revenue          90 non-null     int64
#  6   expenses         90 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 5.1+ KB

# %%
# Descriptive Statistics

describe_data(metrics_data)
# Out:
# --- Statistiques descriptives ---
# ====================================
#
#
#               date  newAdmissions  discharges  emergencyVisits  surgeries  \
# count           90      90.000000   90.000000        90.000000  90.000000
# unique          90            NaN         NaN              NaN        NaN
# top     2025-12-16            NaN         NaN              NaN        NaN
# freq             1            NaN         NaN              NaN        NaN
# mean           NaN      14.877778   12.288889        38.488889   9.166667
# std            NaN       6.001550    4.802257        11.469789   4.062019
# min            NaN       5.000000    5.000000        20.000000   3.000000
# 25%            NaN      10.250000    8.000000        30.000000   5.000000
# 50%            NaN      14.500000   12.000000        35.500000  10.000000
# 75%            NaN      20.000000   16.000000        48.750000  13.000000
# max            NaN      25.000000   20.000000        60.000000  15.000000
#
#              revenue       expenses
# count       90.00000      90.000000
# unique           NaN            NaN
# top              NaN            NaN
# freq             NaN            NaN
# mean     94185.20000   78058.755556
# std      30656.89071   21484.501486
# min      50180.00000   40118.000000
# 25%      67307.00000   59118.000000
# 50%      91878.50000   78975.000000
# 75%     122274.75000   95144.250000
# max     149902.00000  119176.000000

# %%
# Explore unique values

unique_values(metrics_data)
# Out:
# --- Valeurs uniques par colonne ---
# ====================================
#
#
# date : 90 valeurs uniques
# ---------------------------------------
# newAdmissions : 21 valeurs uniques
# ---------------------------------------
# discharges : 16 valeurs uniques
# ---------------------------------------
# emergencyVisits : 38 valeurs uniques
# ---------------------------------------
# surgeries : 13 valeurs uniques
# ---------------------------------------
# revenue : 90 valeurs uniques
# ---------------------------------------
# expenses : 90 valeurs uniques
# ---------------------------------------

# %% [markdown]
# ### **Checking and Handling : Missing values**

# %%
def missing_values(data):
  print("\n--- Valeurs manquantes par colonne ---")
  print("====================================")
  print("     ")
  print("     ")
  print(data.isnull().sum())

# %%
# Patient Data

missing_values(patient_data)
# Out:
# --- Valeurs manquantes par colonne ---
# ====================================
#
#
# patientId             0
# age                   0
# gender                0
# department            0
# admissionDate         0
# dischargeDate       203
# stayDuration          0
# treatment             0
# outcome               0
# treatmentCost         0
# insuranceCovered      0
# isAdmitted            0
# dtype: int64

# %% [markdown]
# **Reminder** :
#
# ---
#
#
#
# dischargeDate : nulle si le patient est toujours hospitalisé.

# %%
# Staff Data

missing_values(staff_data)
# Out:
# --- Valeurs manquantes par colonne ---
# ====================================
#
#
# staffId             0
# department          0
# role                0
# yearsOfService      0
# salary              0
# patientsHandled     0
# performanceScore    0
# dtype: int64

# %%
# Departement Data

missing_values(department_data)
# Out:
# --- Valeurs manquantes par colonne ---
# ====================================
#
#
# department           0
# totalPatients        0
# avgStayDuration      0
# totalRevenue         0
# totalSalaries        0
# operatingCost        0
# recoveryRate         0
# bedsAvailable        0
# currentlyAdmitted    0
# bedUtilization       0
# staffCount           0
# doctorCount          0
# nurseCount           0
# dtype: int64

# %%
# Daily Metrics

missing_values(metrics_data)
# Out:
# --- Valeurs manquantes par colonne ---
# ====================================
#
#
# date               0
# newAdmissions      0
# discharges         0
# emergencyVisits    0
# surgeries          0
# revenue            0
# expenses           0
# dtype: int64

# %% [markdown]
# ### **Checking and Handling :Outliers Handling**
#
# - Check outliers
# - Check Distribution
# - Handle Outliers

# %%
import plotly.express as px

# %%
for col in patient_data.columns:
  if patient_data[col].dtype != "object" :
    if patient_data[col].dtype != "bool":
      print(f"Column {patient_data[col].name} : {patient_data[col].dtype}")
# Out:
# Column age : int64
# Column stayDuration : int64
# Column treatmentCost : int64
# Column insuranceCovered : int64

# %%
def check_outliers(data, columns):
  for col in columns:
    if data[col].dtype != "object" :
      if data[col].dtype != "bool":
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = data[(data[col] < lower_bound) | (data[col] > upper_bound)]
        px.box(data, x=col).show()

# %%
# Patient data
print("     ")
print("     ")
print("====================================")
print("PATIENT DATA")
print("====================================")
print("     ")
print("     ")
check_outliers(patient_data, patient_data.columns)
# Out:
#
#
# ====================================
# PATIENT DATA
# ====================================
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d20c95e9-7e2e-474d-924b-51e7f6db4ee2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d20c95e9-7e2e-474d-924b-51e7f6db4ee2")) {                    Plotly.newPlot(                        "d20c95e9-7e2e-474d-924b-51e7f6db4ee2",                        [{"alignmentgroup":"True","hovertemplate":"age=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":
" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c4385a2-ad99-47c3-a1a5-b9452a8c261e")) {                    Plotly.newPlot(                        "0c4385a2-ad99-47c3-a1a5-b9452a8c261e",                        [{"alignmentgroup":"True","hovertemplate":"avgStayDuration=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[14.15,13.43,13.24,13.94,13.85,13.46],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar", ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c94e644b-cde6-4f26-9e1d-77d29bf03d92" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c94e644b-cde6-4f26-9e1d-77d29bf03d92")) {                    Plotly.newPlot(                        "c94e644b-cde6-4f26-9e1d-77d29bf03d92",                        [{"alignmentgroup":"True","hovertemplate":"totalRevenue=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[7493272,8622894,9352024,6866343,8242040,14540510],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scat ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="99531b99-a7c4-4734-bc3b-11489d37fb54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99531b99-a7c4-4734-bc3b-11489d37fb54")) {                    Plotly.newPlot(                        "99531b99-a7c4-4734-bc3b-11489d37fb54",                        [{"alignmentgroup":"True","hovertemplate":"totalSalaries=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[3014640,2658000,3014600,2785000,1986200,3245040],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scat ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b7a69cf6-6f02-4f56-916d-db9a86a1224f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7a69cf6-6f02-4f56-916d-db9a86a1224f")) {                    Plotly.newPlot(                        "b7a69cf6-6f02-4f56-916d-db9a86a1224f",                        [{"alignmentgroup":"True","hovertemplate":"operatingCost=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[3162214,2842455,3143117,2876917,2163947,3369961],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scat ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e0695396-2fb1-412a-86c8-fa0c3f8c0687" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0695396-2fb1-412a-86c8-fa0c3f8c0687")) {                    Plotly.newPlot(                        "e0695396-2fb1-412a-86c8-fa0c3f8c0687",                        [{"alignmentgroup":"True","hovertemplate":"recoveryRate=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[0.88,0.86,0.85,0.82,0.75,0.85],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9efa8a8c-723c-48e3-a79f-d13f1ca3cd0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9efa8a8c-723c-48e3-a79f-d13f1ca3cd0a")) {                    Plotly.newPlot(                        "9efa8a8c-723c-48e3-a79f-d13f1ca3cd0a",                        [{"alignmentgroup":"True","hovertemplate":"bedsAvailable=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[50,40,60,45,30,35],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6dd99e37-22ab-4e08-a50a-4d3ca9e91734" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6dd99e37-22ab-4e08-a50a-4d3ca9e91734")) {                    Plotly.newPlot(                        "6dd99e37-22ab-4e08-a50a-4d3ca9e91734",                        [{"alignmentgroup":"True","hovertemplate":"currentlyAdmitted=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[36,38,33,37,30,29],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"color ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1b09f03c-853f-4c65-ad65-8fd71bcc4063" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b09f03c-853f-4c65-ad65-8fd71bcc4063")) {                    Plotly.newPlot(                        "1b09f03c-853f-4c65-ad65-8fd71bcc4063",                        [{"alignmentgroup":"True","hovertemplate":"bedUtilization=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[0.72,0.95,0.55,0.82,1.0,0.83],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="99323057-58e9-4be0-9823-067b7bfad485" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99323057-58e9-4be0-9823-067b7bfad485")) {                    Plotly.newPlot(                        "99323057-58e9-4be0-9823-067b7bfad485",                        [{"alignmentgroup":"True","hovertemplate":"staffCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[26,27,33,33,23,30],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0bf20e88-37a4-4395-8626-e25534b9fac7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0bf20e88-37a4-4395-8626-e25534b9fac7")) {                    Plotly.newPlot(                        "0bf20e88-37a4-4395-8626-e25534b9fac7",                        [{"alignmentgroup":"True","hovertemplate":"doctorCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[9,8,9,4,4,5],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outli ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6bd6cd37-9a63-48cd-925b-584bf9d1b6a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6bd6cd37-9a63-48cd-925b-584bf9d1b6a5")) {                    Plotly.newPlot(                        "6bd6cd37-9a63-48cd-925b-584bf9d1b6a5",                        [{"alignmentgroup":"True","hovertemplate":"nurseCount=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[5,3,3,8,3,6],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlin ...

# %%
# Daily Metrics data

print("     ")
print("     ")
print("====================================")
print("DAILY METRICS DATA")
print("====================================")
print("     ")
print("     ")
check_outliers(metrics_data, metrics_data.columns)
# Out:
#
#
# ====================================
# DAILY METRICS DATA
# ====================================
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="959d3053-e9d3-47c4-b02c-ee8500c983a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("959d3053-e9d3-47c4-b02c-ee8500c983a8")) {                    Plotly.newPlot(                        "959d3053-e9d3-47c4-b02c-ee8500c983a8",                        [{"alignmentgroup":"True","hovertemplate":"newAdmissions=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[11,24,23,23,18,11,5,12,17,24,8,16,7,18,6,11,21,6,9,9,22,23,18,22,12,13,18,16,24,24,20,5,19,14,12,5,10,7,8,17,12,23,12,10,19,16,17,6,10,22,22,18,14,17,11,8,5,9,20,14,11,24,12,7,12,14,25,11,20,12,6,12,16,23,20,25,7,15,12,12,21,23,10,16,22,20,15,5,17,21],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","w ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="30cc414a-7cec-45a5-b236-63a8bb2b5e1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30cc414a-7cec-45a5-b236-63a8bb2b5e1f")) {                    Plotly.newPlot(                        "30cc414a-7cec-45a5-b236-63a8bb2b5e1f",                        [{"alignmentgroup":"True","hovertemplate":"discharges=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[12,17,14,16,11,8,11,20,15,20,15,18,6,8,17,15,7,16,19,14,9,5,17,6,14,10,12,7,8,19,10,7,11,5,16,15,18,8,20,10,7,8,5,6,15,20,14,16,19,7,5,10,6,12,13,15,9,6,8,7,15,12,19,10,13,18,13,15,9,13,6,20,9,20,20,5,19,20,8,10,15,5,19,15,10,10,9,10,8,17],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pat ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="45a9c1ae-897e-48ee-a3e4-eda5232fa618" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45a9c1ae-897e-48ee-a3e4-eda5232fa618")) {                    Plotly.newPlot(                        "45a9c1ae-897e-48ee-a3e4-eda5232fa618",                        [{"alignmentgroup":"True","hovertemplate":"emergencyVisits=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[30,30,20,39,38,58,24,29,26,43,59,54,41,60,52,37,49,21,36,24,26,35,31,54,41,33,35,57,58,22,31,31,23,51,38,56,48,49,41,33,58,30,36,33,27,47,52,35,23,52,35,55,33,50,30,36,58,27,41,25,27,52,38,28,29,55,37,42,44,32,23,48,47,34,35,31,52,33,60,21,54,25,45,28,28,35,32,25,34,44],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8e0cee6a-3cc2-4e0d-8973-9abcfff7940a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e0cee6a-3cc2-4e0d-8973-9abcfff7940a")) {                    Plotly.newPlot(                        "8e0cee6a-3cc2-4e0d-8973-9abcfff7940a",                        [{"alignmentgroup":"True","hovertemplate":"surgeries=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[10,15,3,6,4,7,11,8,5,4,8,11,7,15,14,15,4,12,12,10,3,5,10,14,3,9,9,10,9,7,4,11,3,14,11,9,15,12,5,13,10,15,3,14,3,10,8,14,4,11,4,7,4,5,13,4,4,14,10,10,13,3,10,13,10,14,5,5,13,15,5,6,14,7,13,8,3,14,4,15,14,6,14,11,15,9,10,15,6,11],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillm ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="542144c7-ba7a-4e30-a757-1d54305b1f66" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("542144c7-ba7a-4e30-a757-1d54305b1f66")) {                    Plotly.newPlot(                        "542144c7-ba7a-4e30-a757-1d54305b1f66",                        [{"alignmentgroup":"True","hovertemplate":"revenue=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[67703,63411,108100,58816,60234,149902,75983,55849,65298,91829,119585,56941,144911,88009,75035,96699,57401,127770,111851,140820,69419,138461,60649,82200,110959,79457,81804,67175,142773,53435,68773,91928,133167,130841,129969,59003,126199,53848,143914,61014,59581,56133,133029,71109,61051,111437,119841,122908,84591,148611,98909,58033,93610,145026,84271,74865,83591,85771,131376,95318,145862,95403,120375,101324,71534,59658,112383,144128,135936,116859,105291,68071,110997,92159,65034,56176,113382,67951,68265,50180,127928,126053,130120,76602,123264,68742,51478,94643,97998,58676],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"sol ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="65415256-c402-47dc-876c-8ecd9cec42ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65415256-c402-47dc-876c-8ecd9cec42ba")) {                    Plotly.newPlot(                        "65415256-c402-47dc-876c-8ecd9cec42ba",                        [{"alignmentgroup":"True","hovertemplate":"expenses=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[84040,98132,58997,91609,68298,95572,43978,100066,48821,89943,59481,93042,46667,40118,78635,95969,99796,67426,109350,83349,109290,49548,85326,112740,84295,46063,77066,115772,68456,84039,46049,67613,62720,73891,42950,40494,70466,89859,78897,53488,83957,74023,119176,43952,85386,71645,87483,100041,97702,115373,104856,44403,55602,93861,60910,96765,68423,73269,116027,117983,65106,47391,100399,102462,98821,57254,56900,55523,76454,79109,97194,76109,52387,78448,80349,79159,91512,79053,108106,104712,77006,56378,93389,88905,90296,54089,60647,52551,56195,86236],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":" ...

# %% [markdown]
# ##### **Check Distributions of Numeric values**

# %%
# Count element per value
def nunique_values(data):
  for col in data.columns:
    if data[col].nunique() < 10 :
      print(f"{col} : {data[col].value_counts()} valeurs uniques")
      print("---------------------------------------")

# %%
# Patient Data

nunique_values(patient_data)
# Out:
# gender : gender
# Male      529
# Female    471
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# department : department
# Surgery       191
# Neurology     172
# Pediatrics    170
# Oncology      160
# Emergency     156
# Cardiology    151
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# treatment : treatment
# Medication        216
# Surgery           211
# Observation       202
# Therapy           186
# Intensive Care    185
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# outcome : outcome
# Recovered       482
# In Treatment    203
# Improved        184
# Stable           74
# Deteriorated     40
# Deceased         17
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# isAdmitted : isAdmitted
# False    797
# True     203
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------

# %%
# Staff Data

nunique_values(staff_data)
# Out:
# department : department
# Pediatrics        33
# Oncology          33
# Surgery           30
# Administration    28
# Neurology         27
# Cardiology        26
# Emergency         23
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# role : role
# Administrative    51
# Doctor            46
# Technician        38
# Nurse             34
# Support           31
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------

# %%
# Department Data

nunique_values(department_data)
# Out:
# department : department
# Cardiology    1
# Neurology     1
# Oncology      1
# Pediatrics    1
# Emergency     1
# Surgery       1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# totalPatients : totalPatients
# 151    1
# 172    1
# 160    1
# 170    1
# 156    1
# 191    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# avgStayDuration : avgStayDuration
# 14.15    1
# 13.43    1
# 13.24    1
# 13.94    1
# 13.85    1
# 13.46    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# totalRevenue : totalRevenue
# 7493272     1
# 8622894     1
# 9352024     1
# 6866343     1
# 8242040     1
# 14540510    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# totalSalaries : totalSalaries
# 3014640    1
# 2658000    1
# 3014600    1
# 2785000    1
# 1986200    1
# 3245040    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# operatingCost : operatingCost
# 3162214    1
# 2842455    1
# 3143117    1
# 2876917    1
# 2163947    1
# 3369961    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# recoveryRate : recoveryRate
# 0.85    2
# 0.88    1
# 0.86    1
# 0.82    1
# 0.75    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# bedsAvailable : bedsAvailable
# 50    1
# 40    1
# 60    1
# 45    1
# 30    1
# 35    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# currentlyAdmitted : currentlyAdmitted
# 36    1
# 38    1
# 33    1
# 37    1
# 30    1
# 29    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# bedUtilization : bedUtilization
# 0.72    1
# 0.95    1
# 0.55    1
# 0.82    1
# 1.00    1
# 0.83    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# staffCount : staffCount
# 33    2
# 26    1
# 27    1
# 23    1
# 30    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# doctorCount : doctorCount
# 9    2
# 4    2
# 8    1
# 5    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------
# nurseCount : nurseCount
# 3    3
# 5    1
# 8    1
# 6    1
# Name: count, dtype: int64 valeurs uniques
# ---------------------------------------

# %%
# Daily Metrics Data

nunique_values(metrics_data)

# %% [markdown]
# **Note** :
#
# - Le coût du traitement d’un cancer (oncologie) ne sera jamais comparable à celui d’une observation en pédiatrie.
#
# - Un chirurgien senior en cardiologie ne peut pas être comparé à une secrétaire en pédiatrie.

# %%
# Treatment Cost by Department

fig = px.box(patient_data, x='department', y='treatmentCost', color='treatment', title= "Treatment Cost by Department")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="caf11265-b5fe-4b02-bbf4-ba57c7ae1b0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("caf11265-b5fe-4b02-bbf4-ba57c7ae1b0e")) {                    Plotly.newPlot(                        "caf11265-b5fe-4b02-bbf4-ba57c7ae1b0e",                        [{"alignmentgroup":"True","hovertemplate":"treatment=Intensive Care\u003cbr\u003edepartment=%{x}\u003cbr\u003etreatmentCost=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"
])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b46a4c72-1379-4bc3-bc5a-ba7523713110" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b46a4c72-1379-4bc3-bc5a-ba7523713110")) {                    Plotly.newPlot(                        "b46a4c72-1379-4bc3-bc5a-ba7523713110",                        [{"alignmentgroup":"True","hovertemplate":"salary=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[75600,227520,168000,132720,73200,74200,79200,44800,103680,172800,63000,62400,68400,100800,46400,55000,60000,182400,57000,44000,106400,56000,57000,84000,74000,67200,44800,120000,77000,67200,102480,78000,155520,72000,60800,74400,104160,90000,172800,59200,51000,53000,50400,78000,122400,136800,76320,158400,53760,210240,74000,139200,75600,67000,51200,51840,187200,102240,59000,75000,54720,87840,76800,72000,160800,42400,94080,177600,64800,51000,92400,204480,134400,93800,107800,160800,74400,71040,68000,62000,86400,77000,72960,92400,153600,63000,160800,139200,110880,89280,69000,201600,175680,67000,119280,69120,151200,181440,165600,190080,59200,79200,78000,161280,40000,74200,68000,51000,105000,106400,68400,74880,93600,110880,96600,230400,83520,68160,88800,141600,184800,48000,63600,69000,71400,80000,96600,82800,66000,74400,79200,57000,63600,56000,67000,180000,109200,184800,70080,97920,80000,80000,61600,76320,119280,93800,79000,74000,75600,58000,127200,92400,187200,50000,139200,75600,60000,153600,107800,56800,68000,81200,158400,98000,112320,58400,100800,58000,62000,56000,120000,56000,85680,77000,40800,64000,55200,168000,51000,168000,74000,86800,102240,67200,134400,91200,81200,181440,94080,65000,187200,57600,93600,167040,72000,62000,69600,80000,95200,175200],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333 ...

# %%
# Salary by Role and Department

fig = px.box(staff_data, x='role', y='salary', color='department', title= "Salary by Role and Department")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d8e01261-8599-4515-9fdd-e5f7bb175d5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8e01261-8599-4515-9fdd-e5f7bb175d5a")) {                    Plotly.newPlot(                        "d8e01261-8599-4515-9fdd-e5f7bb175d5a",                        [{"alignmentgroup":"True","hovertemplate":"department=Emergency\u003cbr\u003erole=%{x}\u003cbr\u003esalary=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Emergency","marker":{"color":"#636efa"},"name":"Emergency","notched":false,"offsetgroup":"Emergency","orientation":"v","showlegend":true,"x":["Technician","Nurse","Technician","Administrative","Doctor","Support","Administrative","Doctor","Nurse","Administrative","Technician","Administrative","Technician","Administrative","Doctor","Administrative","Doctor","Support","Administrative","Nurse","Administrative","Administrative","Administrative"],"x0":" ","xaxis":"x","y":[75600,74200,79200,63000,172800,50400,59000,177600,92400,62000,86400,51000,63600,56000,184800,80000,139200,56800,68000,81200,62000,77000,74000],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"department=Cardiology\u003cbr\u003erole=%{x}\u003cbr\u003esalary=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cardiology","marker":{"color":"#EF553B"},"name":"Cardiology","notched":false,"offsetgroup":"Cardiology","orientation":"v","showlegend":true,"x":["Doctor","Doctor","Administrative","Nurse","Doctor","Support","Administrative","Doctor","Nurse","Doctor","Support","Nurse","Support","Doctor","Doctor","Doctor","Technician","Support","Nurse","Support","Technician","Administrative","Administrative","Technician","Nurse","Doctor"],"x0":" ","xaxis":"x","y":[227520,172800,62400,102480,155520,72000,74400,158400,94080,204480,72960,110880,69120,181440,190080,161280,83520,68160,109200,70080,76320,75600,60000,100800,94080,167040],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"department=Pediatrics\u003cbr\u003erole=%{x}\u003cbr\u003esalary=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pediatrics","marker":{"color":"#00cc96"},"name":"Pediatrics","notched":false,"offsetgroup":"Pediatrics","orientation":"v","showlegend":true,"x":["Doctor","Administrative","Support","Administrative","Administrative","Administrative","Administrative","Administrative","Technician","Nurse","Technician","Nurse","Administrative","Doctor","Administrative","Administrative","Doctor","Technician","Nurse","Nurse","Technician","Support","Administrative","Nurse","Administrative","Support","Nurse","Nurse","Doctor","Nurse","Support","Administrative","Administrative"],"x0":" ","xaxis":"x","y":[168000,55000,60000,57000,74000,77000,53000,74000,76800,93800,74400,77000,63000,160800,69000,67000,165600,78000,74200,105000,88800,48000,69000,96600,57000,61600,75600,92400,187200,107800,58400,56000,64000],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"department=Surgery\u003cbr\u003erole=%{x}\u003cbr\u003esalary=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Surgery","marker":{"color":"#ab63fa"},"name":"Surgery","notched":false,"offsetgroup":"Surgery","orientation":"v","showlegend":true,"x":["Nurse","Technician","Nurse","Support","Nurse","Technician","Support","Doctor","Support","Technician","Support","Technician","Administrative","Support","Administrative","Technician","Doctor","Doctor","Nurse","Technician","Technician","Technician","Doctor","Technician","Nurse","Technician","Nurse","Technician","Doctor","Administrative"],"x0":" ","xaxis":"x","y":[132720,103680,100800,67200,104160,76320,53760,210240,51840,102240,54720,87840,72000,71040,92400,89280,201600,175680,119280,74880,93600,1108 ...

# %% [markdown]
# **Note** :
#
# - Variability is controlled in each sub-group
#
# - There are no local outliers
#
# - The data generation model is consistent and realistic at subgroup level
#
# **Conclusion** :
#
# - There is no need to delete, winsorise or correct these values
#
# - Keep the data as it is for descriptive analysis, visualisation or even certain models.

# %%
# Filter important roles

patienthandled_filtered = staff_data[staff_data['role'].isin(['Doctor', 'Nurse'])]

# Doctors and nurses are those who handle patients

patienthandled_filtered
# Out:
#     staffId      department    role  yearsOfService  salary  patientsHandled  \
# 1     S1001      Cardiology  Doctor              29  227520               28
# 2     S1002      Pediatrics  Doctor              20  168000               47
# 3     S1003         Surgery   Nurse              29  132720               99
# 5     S1005       Emergency   Nurse               3   74200               53
# 9     S1009      Cardiology  Doctor              10  172800               79
# ..      ...             ...     ...             ...     ...              ...
# 188   S1188      Cardiology   Nurse               6   94080               16
# 190   S1190        Oncology  Doctor              28  187200               58
# 193   S1193      Cardiology  Doctor               8  167040               47
# 198   S1198  Administration   Nurse              18   95200               94
# 199   S1199        Oncology  Doctor              23  175200               69
#
#      performanceScore
# 1                0.86
# 2                0.75
# 3                0.86
# 5                0.87
# 9                0.96
# ..                ...
# 188              0.97
# 190              0.80
# 193              0.89
# 198              0.92
# 199              0.77
#
# [80 rows x 7 columns]

# %%
# metrics_data.merge(patienthandled_filtered, on='staffId', how='inner')

# %%
#patienthandled_filtered.groupby('role')['patientsPerYear'].describe()

# %%
patienthandled_filtered
# Out:
#     staffId      department    role  yearsOfService  salary  patientsHandled  \
# 1     S1001      Cardiology  Doctor              29  227520               28
# 2     S1002      Pediatrics  Doctor              20  168000               47
# 3     S1003         Surgery   Nurse              29  132720               99
# 5     S1005       Emergency   Nurse               3   74200               53
# 9     S1009      Cardiology  Doctor              10  172800               79
# ..      ...             ...     ...             ...     ...              ...
# 188   S1188      Cardiology   Nurse               6   94080               16
# 190   S1190        Oncology  Doctor              28  187200               58
# 193   S1193      Cardiology  Doctor               8  167040               47
# 198   S1198  Administration   Nurse              18   95200               94
# 199   S1199        Oncology  Doctor              23  175200               69
#
#      performanceScore
# 1                0.86
# 2                0.75
# 3                0.86
# 5                0.87
# 9                0.96
# ..                ...
# 188              0.97
# 190              0.80
# 193              0.89
# 198              0.92
# 199              0.77
#
# [80 rows x 7 columns]

# %%
for col in patienthandled_filtered :
  if patienthandled_filtered[col].dtypes == 'int' or 'float' :
    fig = px.box(patienthandled_filtered, y=col,
             title = f"Boxplot de {col}")
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3029637f-ad29-4b2b-b7b5-db1ce16f899e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3029637f-ad29-4b2b-b7b5-db1ce16f899e")) {                    Plotly.newPlot(                        "3029637f-ad29-4b2b-b7b5-db1ce16f899e",                        [{"alignmentgroup":"True","hovertemplate":"staffId=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":["S1001","S1002","S1003","S1005","S1009","S1013","S1017","S1020","S1023","S1027","S1030","S1032","S1036","S1038","S1044","S1045","S1047","S1049","S1051","S1052","S1056","S1064","S1066","S1067","S1070","S1071","S1072","S1073","S1074","S1075","S1081","S1084","S1086","S1087","S1088","S1091","S1092","S1094","S1096","S1097","S1098","S1099","S1103","S1105","S1108","S1109","S1114","S1115","S1119","S1120","S1124","S1126","S1135","S1136","S1137","S1144","S1145","S1148","S1150","S1151","S1152","S1154","S1157","S1158","S1161","S1162","S1163","S1170","S1172","S1177","S1179","S1181","S1184","S1186","S1187","S1188","S1190","S1193","S1198","S1199"],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}} ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="02d767cc-5943-439d-9277-199b3cfbddeb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02d767cc-5943-439d-9277-199b3cfbddeb")) {                    Plotly.newPlot(                        "02d767cc-5943-439d-9277-199b3cfbddeb",                        [{"alignmentgroup":"True","hovertemplate":"department=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":["Cardiology","Pediatrics","Surgery","Emergency","Cardiology","Surgery","Neurology","Administration","Oncology","Administration","Cardiology","Cardiology","Surgery","Emergency","Neurology","Oncology","Cardiology","Surgery","Neurology","Neurology","Oncology","Neurology","Cardiology","Emergency","Emergency","Cardiology","Administration","Pediatrics","Oncology","Administration","Pediatrics","Oncology","Pediatrics","Neurology","Cardiology","Surgery","Surgery","Surgery","Oncology","Cardiology","Pediatrics","Cardiology","Cardiology","Pediatrics","Pediatrics","Neurology","Administration","Surgery","Oncology","Neurology","Administration","Pediatrics","Neurology","Cardiology","Emergency","Surgery","Administration","Pediatrics","Administration","Pediatrics","Pediatrics","Emergency","Oncology","Pediatrics","Emergency","Oncology","Neurology","Administration","Surgery","Neurology","Administration","Oncology","Administration","Administration","Surgery","Cardiology","Oncology","Cardiology","Administration","Oncology"],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="33b4a177-f34d-4c97-bd7d-c9ba3ec0a6bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33b4a177-f34d-4c97-bd7d-c9ba3ec0a6bf")) {                    Plotly.newPlot(                        "33b4a177-f34d-4c97-bd7d-c9ba3ec0a6bf",                        [{"alignmentgroup":"True","hovertemplate":"role=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":["Doctor","Doctor","Nurse","Nurse","Doctor","Nurse","Doctor","Nurse","Nurse","Doctor","Nurse","Doctor","Nurse","Doctor","Doctor","Doctor","Doctor","Doctor","Doctor","Nurse","Doctor","Doctor","Nurse","Doctor","Nurse","Doctor","Doctor","Nurse","Nurse","Doctor","Nurse","Doctor","Doctor","Doctor","Nurse","Doctor","Doctor","Nurse","Doctor","Doctor","Doctor","Doctor","Doctor","Nurse","Nurse","Nurse","Nurse","Doctor","Doctor","Doctor","Nurse","Nurse","Doctor","Nurse","Doctor","Nurse","Nurse","Nurse","Doctor","Nurse","Doctor","Doctor","Doctor","Nurse","Nurse","Doctor","Nurse","Doctor","Nurse","Doctor","Doctor","Nurse","Doctor","Nurse","Doctor","Nurse","Doctor","Doctor","Nurse","Doctor"],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cd266239-b629-463f-a4ba-d0c2f95cdf75" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd266239-b629-463f-a4ba-d0c2f95cdf75")) {                    Plotly.newPlot(                        "cd266239-b629-463f-a4ba-d0c2f95cdf75",                        [{"alignmentgroup":"True","hovertemplate":"yearsOfService=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[29,20,29,3,10,10,26,26,10,0,11,4,12,22,1,7,5,23,8,4,28,17,6,24,16,21,6,17,27,17,5,14,17,8,16,20,11,21,13,13,19,16,6,3,25,26,19,30,9,27,1,19,25,15,27,21,17,4,3,16,28,8,14,27,8,16,20,0,1,20,20,12,6,8,13,6,28,8,18,23],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"ov ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="59b6e9fa-9c19-4107-8a7e-9bc5531adff6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("59b6e9fa-9c19-4107-8a7e-9bc5531adff6")) {                    Plotly.newPlot(                        "59b6e9fa-9c19-4107-8a7e-9bc5531adff6",                        [{"alignmentgroup":"True","hovertemplate":"salary=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[227520,168000,132720,74200,172800,100800,182400,106400,84000,120000,102480,155520,104160,172800,122400,136800,158400,210240,139200,75600,187200,160800,94080,177600,92400,204480,134400,93800,107800,160800,77000,153600,160800,139200,110880,201600,175680,119280,151200,181440,165600,190080,161280,74200,105000,106400,96600,230400,141600,184800,71400,96600,180000,109200,184800,119280,93800,75600,127200,92400,187200,139200,153600,107800,81200,158400,98000,120000,85680,168000,168000,86800,134400,81200,181440,94080,187200,167040,95200,175200],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoo ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ca1ad345-8334-469c-a5c0-b96d998e5d91" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca1ad345-8334-469c-a5c0-b96d998e5d91")) {                    Plotly.newPlot(                        "ca1ad345-8334-469c-a5c0-b96d998e5d91",                        [{"alignmentgroup":"True","hovertemplate":"patientsHandled=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[28,47,99,53,79,62,12,39,57,94,38,26,85,40,73,67,87,71,71,59,80,90,30,99,46,29,84,52,49,93,94,27,11,36,26,97,88,48,11,55,30,75,76,84,72,92,24,35,35,88,12,73,88,33,29,56,90,64,80,64,20,25,44,37,96,77,17,45,88,55,30,26,45,41,90,16,58,47,94,69],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7aa8bde7-60ba-4698-b11c-c1427e8cd628" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7aa8bde7-60ba-4698-b11c-c1427e8cd628")) {                    Plotly.newPlot(                        "7aa8bde7-60ba-4698-b11c-c1427e8cd628",                        [{"alignmentgroup":"True","hovertemplate":"performanceScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x0":" ","xaxis":"x","y":[0.86,0.75,0.86,0.87,0.96,0.79,0.88,0.72,0.92,0.82,0.94,0.83,0.78,0.78,0.81,0.86,0.96,0.8,0.97,0.76,0.96,0.91,0.8,0.82,0.76,0.98,0.79,0.96,0.86,0.76,0.75,0.86,0.81,0.9,0.96,0.82,0.77,0.98,0.8,0.86,0.76,0.99,0.91,0.88,0.87,0.81,0.99,0.96,0.9,0.76,0.74,0.89,0.76,0.85,0.89,0.88,0.97,0.77,0.9,0.76,0.86,0.85,0.97,0.86,0.88,0.75,0.89,0.94,0.89,0.81,0.87,0.76,0.86,0.72,0.92,0.97,0.8,0.89,0.92,0.77],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colo ...

# %%
import plotly.express as px

fig = px.box(patienthandled_filtered, x='role', y='patientsHandled', color='department',
             title="Handled Patients by Role and Service")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fee8b57a-9b07-498c-bf9a-58b200442621" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fee8b57a-9b07-498c-bf9a-58b200442621")) {                    Plotly.newPlot(                        "fee8b57a-9b07-498c-bf9a-58b200442621",                        [{"alignmentgroup":"True","hovertemplate":"department=Cardiology\u003cbr\u003erole=%{x}\u003cbr\u003epatientsHandled=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cardiology","marker":{"color":"#636efa"},"name":"Cardiology","notched":false,"offsetgroup":"Cardiology","orientation":"v","showlegend":true,"x":["Doctor","Doctor","Nurse","Doctor","Doctor","Nurse","Doctor","Nurse","Doctor","Doctor","Doctor","Nurse","Nurse","Doctor"],"x0":" ","xaxis":"x","y":[28,79,38,26,87,30,29,26,55,75,76,33,16,47],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"department=Pediatrics\u003cbr\u003erole=%{x}\u003cbr\u003epatientsHandled=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pediatrics","marker":{"color":"#EF553B"},"name":"Pediatrics","notched":false,"offsetgroup":"Pediatrics","orientation":"v","showlegend":true,"x":["Doctor","Nurse","Nurse","Doctor","Doctor","Nurse","Nurse","Nurse","Nurse","Nurse","Doctor","Nurse"],"x0":" ","xaxis":"x","y":[47,52,94,11,30,84,72,73,64,64,20,37],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"department=Surgery\u003cbr\u003erole=%{x}\u003cbr\u003epatientsHandled=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Surgery","marker":{"color":"#00cc96"},"name":"Surgery","notched":false,"offsetgroup":"Surgery","orientation":"v","showlegend":true,"x":["Nurse","Nurse","Nurse","Doctor","Doctor","Doctor","Nurse","Doctor","Nurse","Nurse","Doctor"],"x0":" ","xaxis":"x","y":[99,62,85,71,97,88,48,35,56,88,90],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"department=Emergency\u003cbr\u003erole=%{x}\u003cbr\u003epatientsHandled=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Emergency","marker":{"color":"#ab63fa"},"name":"Emergency","notched":false,"offsetgroup":"Emergency","orientation":"v","showlegend":true,"x":["Nurse","Doctor","Doctor","Nurse","Doctor","Doctor","Nurse"],"x0":" ","xaxis":"x","y":[53,40,99,46,29,25,96],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"department=Neurology\u003cbr\u003erole=%{x}\u003cbr\u003epatientsHandled=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Neurology","marker":{"color":"#FFA15A"},"name":"Neurology","notched":false,"offsetgroup":"Neurology","orientation":"v","showlegend":true,"x":["Doctor","Doctor","Doctor","Nurse","Doctor","Doctor","Nurse","Doctor","Doctor","Nurse","Doctor"],"x0":" ","xaxis":"x","y":[12,73,71,59,90,36,92,88,88,17,55],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"department=Administration\u003cbr\u003erole=%{x}\u003cbr\u003epatientsHandled=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Administration","marker":{"color":"#19d3f3"},"name":"Administration","notched":false,"offsetgroup":"Administration","orientation":"v","showlegend":true,"x":["Nurse","Doctor","Doctor","Doctor","Nurse","Nurse","Nurse","Doctor","Doctor","Doctor","Doctor","Nurse","Nurse"],"x0":" ","xaxis":"x","y":[39,94,84,93,24,12,90,80,45,30,45,41,94],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"department=Oncology\u003cbr\u003erole=%{x}\u003cbr\u003epatientsHandled=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oncology","marker":{"color":"#FF6692"},"name":"Oncology","notched":false,"offsetgroup":"Oncology","orientation":"v","showlegend":true,"x":["Nurse","Doctor","Doctor","Nurs ...

# %% [markdown]
# ##### **Handle Outliers**

# %%
outlier = patienthandled_filtered[patienthandled_filtered['patientsHandled'] == 21]
outlier
# Out:
# Empty DataFrame
# Columns: [staffId, department, role, yearsOfService, salary, patientsHandled, performanceScore]
# Index: []

# %%
#Q1 = patienthandled_filtered['patientsHandled'].quantile(0.25)
#Q3 = patienthandled_filtered['patientsHandled'].quantile(0.75)
#IQR = Q3 - Q1
#upper_bound = Q3 + 1.5 * IQR
#ower_bound = Q1 - 1.5 * IQR

# Flatten the upper outliers

#patienthandled_filtered['patientsHandled'] = np.clip(patienthandled_filtered['patientsHandled'], None, upper_bound)
#patienthandled_filtered['patientsHandled'] = np.clip(patienthandled_filtered['patientsHandled'], None, lower_bound)

# %%
#import plotly.express as px

#fig = px.box(patienthandled_filtered, x='role', y='patientsHandled', color='department',
             #title="Handled Patients by Role and Service")
#fig.show()

# %%
# Delete the row

staff_data = staff_data[staff_data['staffId'] != 'S1116']

# %%
# Verification

staff_data[staff_data['staffId'] == 'S1116']
# Out:
# Empty DataFrame
# Columns: [staffId, department, role, yearsOfService, salary, patientsHandled, performanceScore]
# Index: []

# %%
# Customised thresholds

patienthandled_filtered['charge'] = pd.cut(patienthandled_filtered['patientsHandled'],
                               bins=[0, 10, 25, 50, 100],
                               labels=['Low', 'Moderate', 'High', 'Intense'])

# %%
patienthandled_filtered
# Out:
#     staffId      department    role  yearsOfService  salary  patientsHandled  \
# 1     S1001      Cardiology  Doctor              29  227520               28
# 2     S1002      Pediatrics  Doctor              20  168000               47
# 3     S1003         Surgery   Nurse              29  132720               99
# 5     S1005       Emergency   Nurse               3   74200               53
# 9     S1009      Cardiology  Doctor              10  172800               79
# ..      ...             ...     ...             ...     ...              ...
# 188   S1188      Cardiology   Nurse               6   94080               16
# 190   S1190        Oncology  Doctor              28  187200               58
# 193   S1193      Cardiology  Doctor               8  167040               47
# 198   S1198  Administration   Nurse              18   95200               94
# 199   S1199        Oncology  Doctor              23  175200               69
#
#      performanceScore    charge
# 1                0.86      High
# 2                0.75      High
# 3                0.86   Intense
# 5                0.87   Intense
# 9                0.96   Intense
# ..                ...       ...
# 188              0.97  Moderate
# 190              0.80   Intense
# 193              0.89      High
# 198              0.92   Intense
# 199              0.77   Intense
#
# [80 rows x 8 columns]

# %%
# Save the final dataset

staff_data.to_json('./data/staff_cleaned.json', orient='records', indent=2)

# %% [markdown]
# ## **Data Analysis**

# %% [markdown]
# ### **Job Analysis/Statistics**
#
# - Moyenne, médiane par groupe
#
# - Comparaison de revenus entre services
#
# - Ratio coût/assurance par traitement

# %%
# Average and median treatmentCost by service/

Cost_summary = patient_data.groupby('department')['treatmentCost'].agg(['mean', 'median', 'std']).reset_index().sort_values(by='mean', ascending=False)
#Cost_summary

# %%
Cost_summary_ = Cost_summary.style \
    .background_gradient(subset=['mean'], cmap='YlGnBu') \
    .background_gradient(subset=['median'], cmap='YlOrRd') \
    .background_gradient(subset=['std'], cmap='Purples') \
    .format({
        'mean': "{:,.0f} $",
        'median': "{:,.0f} $",
        'std': "{:,.0f} $"
    }) \
    .set_caption("Mean, Median, Std by Department")

Cost_summary_
# Out:
# <style type="text/css">
# #T_8892c_row0_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_8892c_row0_col2 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_8892c_row0_col3 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_8892c_row1_col1 {
#   background-color: #3fb4c4;
#   color: #f1f1f1;
# }
# #T_8892c_row1_col2 {
#   background-color: #f64227;
#   color: #f1f1f1;
# }
# #T_8892c_row1_col3 {
#   background-color: #c1c2df;
#   color: #000000;
# }
# #T_8892c_row2_col1 {
#   background-color: #8ed3ba;
#   color: #000000;
# }
# #T_8892c_row2_col2 {
#   background-color: #fea546;
#   color: #000000;
# }
# #T_8892c_row2_col3 {
#   background-color: #bcbddc;
#   color: #000000;
# }
# #T_8892c_row3_col1 {
#   background-color: #bbe4b5;
#   color: #000000;
# }
# #T_8892c_row3_col2 {
#   background-color: #fea245;
#   color: #000000;
# }
# #T_8892c_row3_col3 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_8892c_row4_col1 {
#   background-color: #c2e7b4;
#   color: #000000;
# }
# #T_8892c_row4_col2 {
#   background-color: #fec35e;
#   color: #000000;
# }
# #T_8892c_row4_col3 {
#   background-color: #e0dfee;
#   color: #000000;
# }
# #T_8892c_row5_col1 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_8892c_row5_col2 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_8892c_row5_col3 {
#   background-color: #f2f0f7;
#   color: #000000;
# }
# </style>
# <table id="T_8892c" class="dataframe">
#   <caption>Mean, Median, Std by Department</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8892c_level0_col0" class="col_heading level0 col0" >department</th>
#       <th id="T_8892c_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_8892c_level0_col2" class="col_heading level0 col2" >median</th>
#       <th id="T_8892c_level0_col3" class="col_heading level0 col3" >std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8892c_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_8892c_row0_col0" class="data row0 col0" >Surgery</td>
#       <td id="T_8892c_row0_col1" class="data row0 col1" >76,128 $</td>
#       <td id="T_8892c_row0_col2" class="data row0 col2" >61,202 $</td>
#       <td id="T_8892c_row0_col3" class="data row0 col3" >58,879 $</td>
#     </tr>
#     <tr>
#       <th id="T_8892c_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_8892c_row1_col0" class="data row1 col0" >Oncology</td>
#       <td id="T_8892c_row1_col1" class="data row1 col1" >58,450 $</td>
#       <td id="T_8892c_row1_col2" class="data row1 col2" >47,864 $</td>
#       <td id="T_8892c_row1_col3" class="data row1 col3" >47,909 $</td>
#     </tr>
#     <tr>
#       <th id="T_8892c_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_8892c_row2_col0" class="data row2 col0" >Emergency</td>
#       <td id="T_8892c_row2_col1" class="data row2 col1" >52,834 $</td>
#       <td id="T_8892c_row2_col2" class="data row2 col2" >38,636 $</td>
#       <td id="T_8892c_row2_col3" class="data row2 col3" >48,351 $</td>
#     </tr>
#     <tr>
#       <th id="T_8892c_level0_row3" class="row_heading level0 row3" >2</th>
#       <td id="T_8892c_row3_col0" class="data row3 col0" >Neurology</td>
#       <td id="T_8892c_row3_col1" class="data row3 col1" >50,133 $</td>
#       <td id="T_8892c_row3_col2" class="data row3 col2" >39,066 $</td>
#       <td id="T_8892c_row3_col3" class="data row3 col3" >41,949 $</td>
#     </tr>
#     <tr>
#       <th id="T_8892c_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_8892c_row4_col0" class="data row4 col0" >Cardiology</td>
#       <td id="T_8892c_row4_col1" class="data row4 col1" >49,624 $</td>
#       <td id="T_8892c_row4_col2" class="data row4 col2" >34,970 $</td>
#       <td id="T_8892c_row4_col3" class="data row4 col3" >45,628 $</td>
#     </tr>
#     <tr>
#       <th id="T_8892c_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_8892c_row5_col0" class="data row5 col0" >Pediatrics</td>
#       <td id="T_8892c_row5_col1" class="data row5 col1" >40,390 $</td>
#       <td id="T_8892c_row5_col2" class="data row5 col2" >22,426 $</td>
#       <td id="T_8892c_row5_col3" class="data row5 col3" >43,593 $</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **Salary Analysis**

# %%
department_colors = {
    'Surgery':       {'bg': '#E3F2FD', 'text': '#0D47A1'},  # Bleu clair + bleu foncé
    'Cardiology':    {'bg': '#FCE4EC', 'text': '#AD1457'},  # Rose pâle + rose foncé
    'Neurology':     {'bg': '#EDE7F6', 'text': '#4527A0'},  # Lavande + violet foncé
    'Pediatrics':    {'bg': '#E8F5E9', 'text': '#1B5E20'},  # Vert menthe + vert foncé
    'Emergency':     {'bg': '#FFF8E1', 'text': '#FF6F00'},  # Jaune doux + orange foncé
    'Oncology':      {'bg': '#FFEBEE', 'text': '#B71C1C'},  # Rouge clair + rouge foncé
    'Administration':{'bg': '#E3F2FD', 'text': '#1565C0'},  # Bleu clair + bleu classique
}

# %%
def style_department(row):
    dept = row['department']
    if dept in department_colors:
        bg = department_colors[dept]['bg']
        text = department_colors[dept]['text']
        return [f'background-color: {bg}; color: {text};'] * len(row)
    return [''] * len(row)

# %%
def highlight_salary(val):
    if val > 150000:
        return 'background-color: #D1C4E9; color: #311B92; font-weight: bold;'  # Violet doux
    elif val > 100000:
        return 'background-color: #FFF9C4; color: #F57F17;'  # Jaune pastel
    return 'background-color: #FFCDD2; color: #C62828;'      # Rouge clair

# %%
styled_df = staff_data[['staffId', 'department', 'role', 'salary']].sort_values('salary', ascending=False)

styled_df.style \
    .applymap(highlight_salary, subset=['salary']) \
    .apply(style_department, axis=1) \
    .bar(subset=['salary'], color='#A5D6A7') \
    .set_caption("Salaires du personnel hospitalier — codés par service & hiérarchie")
# Out:
# /tmp/ipykernel_298/4284644361.py:4: FutureWarning:
#
# Styler.applymap has been deprecated. Use Styler.map instead.
# <style type="text/css">
# #T_53770_row0_col0, #T_53770_row0_col1, #T_53770_row0_col2, #T_53770_row2_col0, #T_53770_row2_col1, #T_53770_row2_col2, #T_53770_row4_col0, #T_53770_row4_col1, #T_53770_row4_col2, #T_53770_row12_col0, #T_53770_row12_col1, #T_53770_row12_col2, #T_53770_row16_col0, #T_53770_row16_col1, #T_53770_row16_col2, #T_53770_row42_col0, #T_53770_row42_col1, #T_53770_row42_col2, #T_53770_row47_col0, #T_53770_row47_col1, #T_53770_row47_col2, #T_53770_row48_col0, #T_53770_row48_col1, #T_53770_row48_col2, #T_53770_row49_col0, #T_53770_row49_col1, #T_53770_row49_col2, #T_53770_row50_col0, #T_53770_row50_col1, #T_53770_row50_col2, #T_53770_row58_col0, #T_53770_row58_col1, #T_53770_row58_col2, #T_53770_row59_col0, #T_53770_row59_col1, #T_53770_row59_col2, #T_53770_row61_col0, #T_53770_row61_col1, #T_53770_row61_col2, #T_53770_row62_col0, #T_53770_row62_col1, #T_53770_row62_col2, #T_53770_row63_col0, #T_53770_row63_col1, #T_53770_row63_col2, #T_53770_row66_col0, #T_53770_row66_col1, #T_53770_row66_col2, #T_53770_row74_col0, #T_53770_row74_col1, #T_53770_row74_col2, #T_53770_row77_col0, #T_53770_row77_col1, #T_53770_row77_col2, #T_53770_row81_col0, #T_53770_row81_col1, #T_53770_row81_col2, #T_53770_row83_col0, #T_53770_row83_col1, #T_53770_row83_col2, #T_53770_row86_col0, #T_53770_row86_col1, #T_53770_row86_col2, #T_53770_row107_col0, #T_53770_row107_col1, #T_53770_row107_col2, #T_53770_row113_col0, #T_53770_row113_col1, #T_53770_row113_col2, #T_53770_row126_col0, #T_53770_row126_col1, #T_53770_row126_col2, #T_53770_row129_col0, #T_53770_row129_col1, #T_53770_row129_col2, #T_53770_row131_col0, #T_53770_row131_col1, #T_53770_row131_col2, #T_53770_row143_col0, #T_53770_row143_col1, #T_53770_row143_col2, #T_53770_row180_col0, #T_53770_row180_col1, #T_53770_row180_col2, #T_53770_row181_col0, #T_53770_row181_col1, #T_53770_row181_col2, #T_53770_row183_col0, #T_53770_row183_col1, #T_53770_row183_col2 {
#   background-color: #E3F2FD;
#   color: #0D47A1;
# }
# #T_53770_row0_col3 {
#   background-color: #D1C4E9;
#   color: #311B92;
#   font-weight: bold;
#   background-color: #E3F2FD;
#   color: #0D47A1;
#   width: 10em;
#   background: linear-gradient(90deg, #A5D6A7 100.0%, transparent 100.0%);
# }
# #T_53770_row1_col0, #T_53770_row1_col1, #T_53770_row1_col2, #T_53770_row3_col0, #T_53770_row3_col1, #T_53770_row3_col2, #T_53770_row5_col0, #T_53770_row5_col1, #T_53770_row5_col2, #T_53770_row13_col0, #T_53770_row13_col1, #T_53770_row13_col2, #T_53770_row18_col0, #T_53770_row18_col1, #T_53770_row18_col2, #T_53770_row23_col0, #T_53770_row23_col1, #T_53770_row23_col2, #T_53770_row25_col0, #T_53770_row25_col1, #T_53770_row25_col2, #T_53770_row29_col0, #T_53770_row29_col1, #T_53770_row29_col2, #T_53770_row31_col0, #T_53770_row31_col1, #T_53770_row31_col2, #T_53770_row51_col0, #T_53770_row51_col1, #T_53770_row51_col2, #T_53770_row52_col0, #T_53770_row52_col1, #T_53770_row52_col2, #T_53770_row60_col0, #T_53770_row60_col1, #T_53770_row60_col2, #T_53770_row64_col0, #T_53770_row64_col1, #T_53770_row64_col2, #T_53770_row70_col0, #T_53770_row70_col1, #T_53770_row70_col2, #T_53770_row71_col0, #T_53770_row71_col1, #T_53770_row71_col2, #T_53770_row106_col0, #T_53770_row106_col1, #T_53770_row106_col2, #T_53770_row110_col0, #T_53770_row110_col1, #T_53770_row110_col2, #T_53770_row114_col0, #T_53770_row114_col1, #T_53770_row114_col2, #T_53770_row124_col0, #T_53770_row124_col1, #T_53770_row124_col2, #T_53770_row127_col0, #T_53770_row127_col1, #T_53770_row127_col2, #T_53770_row130_col0, #T_53770_row130_col1, #T_53770_row130_col2, #T_53770_row132_col0, #T_53770_row132_col1, #T_53770_row132_col2, #T_53770_row137_col0, #T_53770_row137_col1, #T_53770_row137_col2, #T_53770_row155_col0, #T_53770_row155_col1, #T_53770_row155_col2, #T_53770_row161_col0, #T_53770_row161_col1, #T_53770_row161_col2 {
#   background-color: #FCE4EC;
#   color: #AD1457;
# }
# #T_53770_row1_col3 {
#   background-color: #D1C4E9;
#   color: #311B92;
#   font-weight: bold;
#   background-color: #FCE4EC;
#   color: #AD1457;
#   width: 10em;
#   background: linear-gradient(90deg, #A5D6A7 98.8%, transparent 98.8%);
# }
# #T_53770_row2_col3 {
#   background-color: #D1C4E9;
#   color: #311B92;
#   font-weight: bold;
#   background-color: #E3F2FD;
#   color: #0D47A1;
#   width: 10em;
#   background: linear-gradient(90deg, #A5D6A7 91.2%, transparent 91.2%);
# }
# #T_53770_row3_col3 {
#   background-color: #D1C4E9;
#   color: #311B92;
#   font-weight: bold;
#   background-color: #FCE4EC;
#   color: #AD1457;
#   width: 10em;
#   background: linear-gradient(90deg, #A5D6A7 88.8%, transparent 88.8%);
# }
# #T_53770_row4_col3 {
#   background-color: #D1C4E9;
#   color: #311B92;
#   font-weight: bold;
#   background-color: #E3F2FD;
#   color: #0D47A1;
#   width: 10em;
#   background: linear-gradient(90deg, #A5D6A7 87.5%, transparent 87.5%);
# }
# #T_53770_row5_col3 {
#   background-color: #D1C4E9;
#   color: #311B92;
#   font-weight: bold;
#   background-color: #FCE4EC;
#   color: #AD1457;
#   width: 10em;
#   background: linear-gradient(90deg, #A5D6A7 82.5%, transparent 82.5%);
# }
type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"department=Cardiology\u003cbr\u003etreatmentCost=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cardiology","marker":{"color":"rgb(136,65,157)","pattern":{"shape":""}},"name":"Cardiology","nbinsx":30,"offsetgroup":"Cardiology","orientation":"v","showlegend":true,"x":[3891,33205,16209,71986,26611,32396,33610,34825,26586,132220,25283,36797,11012,39879,39783,7885,39984,144156,1650,15677,7 ...

# %%
# Amount covered by insurance

import plotly.express as px

fig = px.histogram(
    patient_data,
    x='insuranceCovered',
    nbins=50,
    color='department',
    barmode='overlay',
    opacity=0.6,
    title="Amount Covered by Insurance (By service)",
    labels={'insuranceCovered': 'Covered amount'},
    color_discrete_sequence=px.colors.sequential.BuPu_r
)

fig.update_layout(
    bargap=0.2,
    xaxis_title='Covered Amount',
    yaxis_title='Number of patients',
    legend_title='Department'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="007f687f-3c94-44bd-ae16-37e442a2f502" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("007f687f-3c94-44bd-ae16-37e442a2f502")) {                    Plotly.newPlot(                        "007f687f-3c94-44bd-ae16-37e442a2f502",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"department=Surgery\u003cbr\u003eCovered amount=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Surgery","marker":{"color":"rgb(77,0,75)","opacity":0.6,"pattern":{"shape":""}},"name":"Surgery","nbinsx":50,"offsetgroup":"Surgery","orientation":"v","showlegend":true,"x":[94618,107068,8122,13058,73021,70862,67550,56125,60883,16096,164579,22239,74519,43712,96409,27517,52564,31104,95168,69726,24881,20088,164711,55758,43379,57003,114502,134372,51401,237459,32974,28194,33771,46969,28639,127080,5250,44930,49891,33904,137219,111236,19602,145783,104977,55480,12920,119150,4928,27308,74569,108316,17404,185597,40390,28324,66846,47972,40242,106558,12860,11569,208192,232666,15028,9972,8291,34699,19665,56099,75253,45264,116080,110080,40347,129885,56530,123438,21503,31861,49766,6900,12067,134307,23588,21659,42151,145450,29670,33009,52519,77908,29253,90076,28438,5720,95666,23499,19804,155404,19452,62318,53470,61043,53049,29976,19416,27203,33442,8747,56203,20548,132517,21120,125287,51537,63820,49361,6810,106960,38232,1786,64231,14836,93089,79328,21274,112042,114958,60314,71867,16843,5611,14020,102782,62005,15516,138616,2728,40466,23558,53333,88896,45671,157834,85848,128611,91055,35629,100710,64181,4685,40203,10803,11057,26464,12497,54784,9320,67066,135854,122690,80750,189808,94946,62535,44208,4257,61591,105289,28670,134879,7454,73879,7441,61417,82156,114661,85700,55528,41446,72024,37689,10848,108912,151696,56039,64595,10031,41545,45758],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"department=Oncology\u003cbr\u003eCovered amount=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"
"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoi ...

# %%
# Average out-of-pocket expenses by department

agg_out_of_pocket = (
    patient_data.groupby('department')['outOfPocket']
    .mean()
    .reset_index()
    .sort_values(by='outOfPocket', ascending=False)
)

fig = px.bar(
    agg_out_of_pocket,
    x='department',
    y='outOfPocket',
    color='department',
    title='Average charges by department',
    labels={'outOfPocket': 'Average amount not covered'},
    color_discrete_sequence=px.colors.sequential.BuPu_r
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e43664e0-8668-459c-b973-c9db34a8a356" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e43664e0-8668-459c-b973-c9db34a8a356")) {                    Plotly.newPlot(                        "e43664e0-8668-459c-b973-c9db34a8a356",                        [{"alignmentgroup":"True","hovertemplate":"department=%{x}\u003cbr\u003eAverage amount not covered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Surgery","marker":{"color":"rgb(77,0,75)","pattern":{"shape":""}},"name":"Surgery","offsetgroup":"Surgery","orientation":"v","showlegend":true,"textposition":"auto","x":["Surgery"],"xaxis":"x","y":[14084.465968586388],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department=%{x}\u003cbr\u003eAverage amount not covered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oncology","marker":{"color":"rgb(129,15,124)","pattern":{"shape":""}},"name":"Oncology","offsetgroup":"Oncology","orientation":"v","showlegend":true,"textposition":"auto","x":["Oncology"],"xaxis":"x","y":[10188.7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department=%{x}\u003cbr\u003eAverage amount not covered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cardiology","marker":{"color":"rgb(136,65,157)","pattern":{"shape":""}},"name":"Cardiology","offsetgroup":"Cardiology","orientation":"v","showlegend":true,"textposition":"auto","x":["Cardiology"],"xaxis":"x","y":[9500.761589403974],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department=%{x}\u003cbr\u003eAverage amount not covered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Emergency","marker":{"color":"rgb(140,107,177)","pattern":{"shape":""}},"name":"Emergency","offsetgroup":"Emergency","orientation":"v","showlegend":true,"textposition":"auto","x":["Emergency"],"xaxis":"x","y":[9139.051282051281],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department=%{x}\u003cbr\u003eAverage amount not covered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Neurology","marker":{"color":"rgb(140,150,198)","pattern":{"shape":""}},"name":"Neurology","offsetgroup":"Neurology","orientation":"v","showlegend":true,"textposition":"auto","x":["Neurology"],"xaxis":"x","y":[8748.453488372093],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department=%{x}\u003cbr\u003eAverage amount not covered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pediatrics","marker":{"color":"rgb(158,188,218)","pattern":{"shape":""}},"name":"Pediatrics","offsetgroup":"Pediatrics","orientation":"v","showlegend":true,"textposition":"auto","x":["Pediatrics"],"xaxis":"x","y":[7089.447058823529],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale": ...

# %%
# Distribution of work loads

fig = px.pie(patienthandled_filtered, names='charge', title="Distribution of work loads", color_discrete_sequence=px.colors.sequential.RdBu)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1ba0401a-d7ae-4873-b17c-3ea3b1266918" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ba0401a-d7ae-4873-b17c-3ea3b1266918")) {                    Plotly.newPlot(                        "1ba0401a-d7ae-4873-b17c-3ea3b1266918",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"charge=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["High","High","Intense","Intense","Intense","Intense","Moderate","High","Intense","Intense","High","High","Intense","High","Intense","Intense","Intense","Intense","Intense","Intense","Intense","Intense","High","Intense","High","High","Intense","Intense","High","Intense","Intense","High","Moderate","High","High","Intense","Intense","High","Moderate","Intense","High","Intense","Intense","Intense","Intense","Intense","Moderate","High","High","Intense","Moderate","Intense","Intense","High","High","Intense","Intense","Intense","Intense","Intense","Moderate","Moderate","High","High","Intense","Intense","Moderate","High","Intense","Intense","High","High","High","High","Intense","Moderate","Intense","High","Intense","Intense"],"legendgroup":"","name":"","showlegend":true,"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter": ...

# %% [markdown]
# ### **Alerts Definition**

# %% [markdown]
# **Critiques** :
#
# - Bed Utilization Rate (Elevé if > 90%)
# - Taux de retablissement faible (if < 70%)
# - Ratio personnel / patient

# %%
alertes = []

# %%
for it in department_data.iterrows():
  #print(it)
  pass

# %%
# Define Alerts

alertes = []

# %%
department_data['bedUtilization'].unique()
# Out:
# array([0.72, 0.95, 0.55, 0.82, 1.  , 0.83])

# %%
# High Bed Utilization Rate

# Serious Alerts

for _, dept in department_data.iterrows():
  # Alerte de taux d'occupation élevé
  if dept['bedUtilization'] > 0.9:
    alertes.append({
    'titre': f"Taux d'occupation critique en {dept['department']}",
    'message': f"Le taux d'occupation des lits est de {dept['bedUtilization']*100:.1f}% ({dept['currentlyAdmitted']} patients pour {dept['bedsAvailable']} lits).",
    'departement': dept['department'],
    'type': 'critique'
    })

alertes
# Out:
# [{'titre': "Taux d'occupation critique en Neurology",
#   'message': "Le taux d'occupation des lits est de 95.0% (38 patients pour 40 lits).",
#   'departement': 'Neurology',
#   'type': 'critique'},
#  {'titre': "Taux d'occupation critique en Emergency",
#   'message': "Le taux d'occupation des lits est de 100.0% (30 patients pour 30 lits).",
#   'departement': 'Emergency',
#   'type': 'critique'}]

# %%
# Low Recovery Rate Alerts

if dept['recoveryRate'] < 0.7:
  alertes.append({
      'titre': f"Taux de rétablissement faible en {dept['department']}",
      'message': f"Le taux de rétablissement est de seulement {dept['recoveryRate']*100:.1f}%, ce qui est inférieur à l'objectif de 70%.",
      'departement': dept['department'],
      'type': 'critique'
      })

alertes
# Out:
# [{'titre': "Taux d'occupation critique en Neurology",
#   'message': "Le taux d'occupation des lits est de 95.0% (38 patients pour 40 lits).",
#   'departement': 'Neurology',
#   'type': 'critique'},
#  {'titre': "Taux d'occupation critique en Emergency",
#   'message': "Le taux d'occupation des lits est de 100.0% (30 patients pour 30 lits).",
#   'departement': 'Emergency',
#   'type': 'critique'}]

# %%
# Ratio Doctor/Patients Alerts

ratio_medecins = dept['doctorCount'] / max(1, dept['totalPatients'])
if ratio_medecins < 0.1:  # Moins de 1 médecin pour 10 patients
  alertes.append({
      'titre': f"Manque de médecins en {dept['department']}",
      'message': f"Ratio médecin/patients de 1:{int(1/ratio_medecins)}, ce qui est inférieur aux recommandations.",
      'departement': dept['department'],
      'type': 'critique'
      })

max(1, dept['totalPatients'])
# Out:
# 191

# %%
print(ratio_medecins)
# Out:
# 0.02617801047120419

# %%
print(alertes)
# Out:
# [{'titre': "Taux d'occupation critique en Neurology", 'message': "Le taux d'occupation des lits est de 95.0% (38 patients pour 40 lits).", 'departement': 'Neurology', 'type': 'critique'}, {'titre': "Taux d'occupation critique en Emergency", 'message': "Le taux d'occupation des lits est de 100.0% (30 patients pour 30 lits).", 'departement': 'Emergency', 'type': 'critique'}, {'titre': 'Manque de médecins en Surgery', 'message': 'Ratio médecin/patients de 1:38, ce qui est inférieur aux recommandations.', 'departement': 'Surgery', 'type': 'critique'}]

# %%
# Ratio Doctor/Patients Alerts

ratio_medecins = dept['doctorCount'] / dept['totalPatients']
if ratio_medecins < 0.1:  # Moins de 1 médecin pour 10 patients
  alertes.append({
      'titre': f"Manque de médecins en {dept['department']}",
      'message': f"Ratio médecin/patients de 1:{int(1/ratio_medecins)}, ce qui est inférieur aux recommandations.",
      'departement': dept['department'],
      'type': 'critique'
      })

alertes
ratio_medecins
# max(1, dept['totalPatients'])
# Out:
# 0.02617801047120419

# %%
# Display Alertes Dataframe

pd.DataFrame(alertes)
# Out:
#                                      titre  \
# 0  Taux d'occupation critique en Neurology
# 1  Taux d'occupation critique en Emergency
# 2            Manque de médecins en Surgery
# 3            Manque de médecins en Surgery
#
#                                              message departement      type
# 0  Le taux d'occupation des lits est de 95.0% (38...   Neurology  critique
# 1  Le taux d'occupation des lits est de 100.0% (3...   Emergency  critique
# 2  Ratio médecin/patients de 1:38, ce qui est inf...     Surgery  critique
# 3  Ratio médecin/patients de 1:38, ce qui est inf...     Surgery  critique

# %% [markdown]
# **Générales**
#
# - Tendance Admission / Sorties
# - Alertes financières

# %%
# Admission vs. Discharges

metrics_data
# Out:
#           date  newAdmissions  discharges  emergencyVisits  surgeries  \
# 0   2025-12-16             11          12               30         10
# 1   2025-12-17             24          17               30         15
# 2   2025-12-18             23          14               20          3
# 3   2025-12-19             23          16               39          6
# 4   2025-12-20             18          11               38          4
# ..         ...            ...         ...              ...        ...
# 85  2026-03-11             20          10               35          9
# 86  2026-03-12             15           9               32         10
# 87  2026-03-13              5          10               25         15
# 88  2026-03-14             17           8               34          6
# 89  2026-03-15             21          17               44         11
#
#     revenue  expenses
# 0     67703     84040
# 1     63411     98132
# 2    108100     58997
# 3     58816     91609
# 4     60234     68298
# ..      ...       ...
# 85    68742     54089
# 86    51478     60647
# 87    94643     52551
# 88    97998     56195
# 89    58676     86236
#
# [90 rows x 7 columns]

# %%
len(metrics_data)
# Out:
# 90

# %%
derniere_semaine = metrics_data.sort_values('date').tail(7)

# %%
admissions = derniere_semaine['newAdmissions'].sum()

admissions
# Out:
# np.int64(116)

# %%
sorties = derniere_semaine['discharges'].sum()

sorties
# Out:
# np.int64(79)

# %%
derniere_semaine
# Out:
#           date  newAdmissions  discharges  emergencyVisits  surgeries  \
# 83  2026-03-09             16          15               28         11
# 84  2026-03-10             22          10               28         15
# 85  2026-03-11             20          10               35          9
# 86  2026-03-12             15           9               32         10
# 87  2026-03-13              5          10               25         15
# 88  2026-03-14             17           8               34          6
# 89  2026-03-15             21          17               44         11
#
#     revenue  expenses
# 83    76602     88905
# 84   123264     90296
# 85    68742     54089
# 86    51478     60647
# 87    94643     52551
# 88    97998     56195
# 89    58676     86236

# %%
# Admissions vs Discharges Trend

if len(metrics_data) >= 7:  # Au moins une semaine de données
    derniere_semaine = metrics_data.sort_values('date').tail(7)
    admissions = derniere_semaine['newAdmissions'].sum()
    sorties = derniere_semaine['discharges'].sum()
    if admissions > sorties * 1.3:  # 30% plus d'admissions que de sorties
      alertes.append({
          'titre': "Déséquilibre admissions/sorties",
          'message': f"Sur les 7 derniers jours, il y a eu {admissions} admissions pour seulement {sorties} sorties, ce qui indique une pression croissante sur les capacités.",
          'departement': 'Tous',
          'type': 'avertissement'
          })

# %%
if len(metrics_data) >= 7:  # Au moins une semaine de données
    derniere_semaine = metrics_data.sort_values('date').tail(7)
    admissions = derniere_semaine['newAdmissions'].sum()
    sorties = derniere_semaine['discharges'].sum()
    if admissions > sorties * 1.3:  # 30% plus d'admissions que de sorties
      alertes.append({
          'titre': "Déséquilibre admissions/sorties",
          'message': f"Sur les 7 derniers jours, il y a eu {admissions} admissions pour seulement {sorties} sorties, ce qui indique une pression croissante sur les capacités.",
          'departement': 'Tous',
          'type': 'avertissement'
          })

alertes
# Out:
# [{'titre': "Taux d'occupation critique en Neurology",
#   'message': "Le taux d'occupation des lits est de 95.0% (38 patients pour 40 lits).",
#   'departement': 'Neurology',
#   'type': 'critique'},
#  {'titre': "Taux d'occupation critique en Emergency",
#   'message': "Le taux d'occupation des lits est de 100.0% (30 patients pour 30 lits).",
#   'departement': 'Emergency',
#   'type': 'critique'},
#  {'titre': 'Manque de médecins en Surgery',
#   'message': 'Ratio médecin/patients de 1:38, ce qui est inférieur aux recommandations.',
#   'departement': 'Surgery',
#   'type': 'critique'},
#  {'titre': 'Manque de médecins en Surgery',
#   'message': 'Ratio médecin/patients de 1:38, ce qui est inférieur aux recommandations.',
#   'departement': 'Surgery',
#   'type': 'critique'},
#  {'titre': 'Déséquilibre admissions/sorties',
#   'message': 'Sur les 7 derniers jours, il y a eu 116 admissions pour seulement 79 sorties, ce qui indique une pression croissante sur les capacités.',
#   'departement': 'Tous',
#   'type': 'avertissement'},
#  {'titre': 'Déséquilibre admissions/sorties',
#   'message': 'Sur les 7 derniers jours, il y a eu 116 admissions pour seulement 79 sorties, ce qui indique une pression croissante sur les capacités.',
#   'departement': 'Tous',
#   'type': 'avertissement'}]

# %%
# Test

if admissions > sorties * 1.3:  # 30% plus d'admissions que de sorties
  alertes.append({
      'titre': "Déséquilibre admissions/sorties",
      'message': f"Sur les 7 derniers jours, il y a eu {admissions} admissions pour seulement {sorties} sorties, ce qui indique une pression croissante sur les capacités.",
      'departement': 'Tous',
      'type': 'avertissement'
      })
  print(alertes)
else:
  print(f"Capacité non pressante : Il y a eu {admissions} admissions pour {sorties} sorties.")
# Out:
# [{'titre': "Taux d'occupation critique en Neurology", 'message': "Le taux d'occupation des lits est de 95.0% (38 patients pour 40 lits).", 'departement': 'Neurology', 'type': 'critique'}, {'titre': "Taux d'occupation critique en Emergency", 'message': "Le taux d'occupation des lits est de 100.0% (30 patients pour 30 lits).", 'departement': 'Emergency', 'type': 'critique'}, {'titre': 'Manque de médecins en Surgery', 'message': 'Ratio médecin/patients de 1:38, ce qui est inférieur aux recommandations.', 'departement': 'Surgery', 'type': 'critique'}, {'titre': 'Manque de médecins en Surgery', 'message': 'Ratio médecin/patients de 1:38, ce qui est inférieur aux recommandations.', 'departement': 'Surgery', 'type': 'critique'}, {'titre': 'Déséquilibre admissions/sorties', 'message': 'Sur les 7 derniers jours, il y a eu 116 admissions pour seulement 79 sorties, ce qui indique une pression croissante sur les capacités.', 'departement': 'Tous', 'type': 'avertissement'}, {'titre': 'Déséquilibre admissions/sorties', 'message': 'Sur les 7 derniers jours, il y a eu 116 admissions pour seulement 79 sorties, ce qui indique une pression croissante sur les capacités.', 'departement': 'Tous', 'type': 'avertissement'}, {'titre': 'Déséquilibre admissions/sorties', 'message': 'Sur les 7 derniers jours, il y a eu 116 admissions pour seulement 79 sorties, ce qui indique une pression croissante sur les capacités.', 'departement': 'Tous', 'type': 'avertissement'}]

# %%
metrics_data
# Out:
#           date  newAdmissions  discharges  emergencyVisits  surgeries  \
# 0   2025-12-16             11          12               30         10
# 1   2025-12-17             24          17               30         15
# 2   2025-12-18             23          14               20          3
# 3   2025-12-19             23          16               39          6
# 4   2025-12-20             18          11               38          4
# ..         ...            ...         ...              ...        ...
# 85  2026-03-11             20          10               35          9
# 86  2026-03-12             15           9               32         10
# 87  2026-03-13              5          10               25         15
# 88  2026-03-14             17           8               34          6
# 89  2026-03-15             21          17               44         11
#
#     revenue  expenses
# 0     67703     84040
# 1     63411     98132
# 2    108100     58997
# 3     58816     91609
# 4     60234     68298
# ..      ...       ...
# 85    68742     54089
# 86    51478     60647
# 87    94643     52551
# 88    97998     56195
# 89    58676     86236
#
# [90 rows x 7 columns]

# %%
# Financial Alerts
if len(metrics_data) >= 30:  # Au moins un mois de données
  dernier_mois = metrics_data.sort_values('date').tail(30)
  revenus = dernier_mois['revenue'].sum()
  depenses = dernier_mois['expenses'].sum()
  if depenses > revenus:
    alertes.append({
        'titre': "Déficit financier",
        'message': f"Sur les 30 derniers jours, les dépenses ({depenses}) ont dépassé les revenus ({revenus}), créant un déficit de {(depenses-revenus)}.",
        'departement': 'Tous',
        'type': 'avertissement'
            })

# %%
# Financial Alerts Test

if len(metrics_data) >= 30:  # Au moins un mois de données
  dernier_mois = metrics_data.sort_values('date').tail(30)
  revenus = dernier_mois['revenue'].sum()
  depenses = dernier_mois['expenses'].sum()
  if depenses > revenus:
    alertes.append({
        'titre': "Déficit financier",
        'message': f"Sur les 30 derniers jours, les dépenses ({depenses}) ont dépassé les revenus ({revenus}), créant un déficit de {(depenses-revenus)}.",
        'departement': 'Tous',
        'type': 'avertissement'
            })
  else :
    print(f"Pas de problème financier : Les revenus ({(revenus)}) sont supérieurs aux dépenses ({(depenses)}), créant un profit de {(revenus-depenses)}.")
# Out:
# Pas de problème financier : Les revenus (2856472) sont supérieurs aux dépenses (2302140), créant un profit de 554332.

# %%
# Display Alert

alertes
# Out:
# [{'titre': "Taux d'occupation critique en Neurology",
#   'message': "Le taux d'occupation des lits est de 95.0% (38 patients pour 40 lits).",
#   'departement': 'Neurology',
#   'type': 'critique'},
#  {'titre': "Taux d'occupation critique en Emergency",
#   'message': "Le taux d'occupation des lits est de 100.0% (30 patients pour 30 lits).",
#   'departement': 'Emergency',
#   'type': 'critique'},
#  {'titre': 'Manque de médecins en Surgery',
#   'message': 'Ratio médecin/patients de 1:38, ce qui est inférieur aux recommandations.',
#   'departement': 'Surgery',
#   'type': 'critique'},
#  {'titre': 'Manque de médecins en Surgery',
#   'message': 'Ratio médecin/patients de 1:38, ce qui est inférieur aux recommandations.',
#   'departement': 'Surgery',
#   'type': 'critique'},
#  {'titre': 'Déséquilibre admissions/sorties',
#   'message': 'Sur les 7 derniers jours, il y a eu 116 admissions pour seulement 79 sorties, ce qui indique une pression croissante sur les capacités.',
#   'departement': 'Tous',
#   'type': 'avertissement'},
#  {'titre': 'Déséquilibre admissions/sorties',
#   'message': 'Sur les 7 derniers jours, il y a eu 116 admissions pour seulement 79 sorties, ce qui indique une pression croissante sur les capacités.',
#   'departement': 'Tous',
#   'type': 'avertissement'},
#  {'titre': 'Déséquilibre admissions/sorties',
#   'message': 'Sur les 7 derniers jours, il y a eu 116 admissions pour seulement 79 sorties, ce qui indique une pression croissante sur les capacités.',
#   'departement': 'Tous',
#   'type': 'avertissement'}]

# %%
# Display Alert Dataframe

pd.DataFrame(alertes)
# Out:
#                                      titre  \
# 0  Taux d'occupation critique en Neurology
# 1  Taux d'occupation critique en Emergency
# 2            Manque de médecins en Surgery
# 3            Manque de médecins en Surgery
# 4          Déséquilibre admissions/sorties
# 5          Déséquilibre admissions/sorties
# 6          Déséquilibre admissions/sorties
#
#                                              message departement  \
# 0  Le taux d'occupation des lits est de 95.0% (38...   Neurology
# 1  Le taux d'occupation des lits est de 100.0% (3...   Emergency
# 2  Ratio médecin/patients de 1:38, ce qui est inf...     Surgery
# 3  Ratio médecin/patients de 1:38, ce qui est inf...     Surgery
# 4  Sur les 7 derniers jours, il y a eu 116 admiss...        Tous
# 5  Sur les 7 derniers jours, il y a eu 116 admiss...        Tous
# 6  Sur les 7 derniers jours, il y a eu 116 admiss...        Tous
#
#             type
# 0       critique
# 1       critique
# 2       critique
# 3       critique
# 4  avertissement
# 5  avertissement
# 6  avertissement

# %% [markdown]
# ### **Recommendations**

# %%
alertes
# Out:
# [{'titre': "Taux d'occupation critique en Neurology",
#   'message': "Le taux d'occupation des lits est de 95.0% (38 patients pour 40 lits).",
#   'departement': 'Neurology',
#   'type': 'critique'},
#  {'titre': "Taux d'occupation critique en Emergency",
#   'message': "Le taux d'occupation des lits est de 100.0% (30 patients pour 30 lits).",
#   'departement': 'Emergency',
#   'type': 'critique'},
#  {'titre': 'Manque de médecins en Surgery',
#   'message': 'Ratio médecin/patients de 1:38, ce qui est inférieur aux recommandations.',
#   'departement': 'Surgery',
#   'type': 'critique'},
#  {'titre': 'Manque de médecins en Surgery',
#   'message': 'Ratio médecin/patients de 1:38, ce qui est inférieur aux recommandations.',
#   'departement': 'Surgery',
#   'type': 'critique'},
#  {'titre': 'Déséquilibre admissions/sorties',
#   'message': 'Sur les 7 derniers jours, il y a eu 116 admissions pour seulement 79 sorties, ce qui indique une pression croissante sur les capacités.',
#   'departement': 'Tous',
#   'type': 'avertissement'},
#  {'titre': 'Déséquilibre admissions/sorties',
#   'message': 'Sur les 7 derniers jours, il y a eu 116 admissions pour seulement 79 sorties, ce qui indique une pression croissante sur les capacités.',
#   'departement': 'Tous',
#   'type': 'avertissement'},
#  {'titre': 'Déséquilibre admissions/sorties',
#   'message': 'Sur les 7 derniers jours, il y a eu 116 admissions pour seulement 79 sorties, ce qui indique une pression croissante sur les capacités.',
#   'departement': 'Tous',
#   'type': 'avertissement'}]

# %%
# Recommendations

recommendations = []

# %%
for a in alertes :
  if "occupation" in a['titre'].lower():
    print(a)
# Out:
# {'titre': "Taux d'occupation critique en Neurology", 'message': "Le taux d'occupation des lits est de 95.0% (38 patients pour 40 lits).", 'departement': 'Neurology', 'type': 'critique'}
# {'titre': "Taux d'occupation critique en Emergency", 'message': "Le taux d'occupation des lits est de 100.0% (30 patients pour 30 lits).", 'departement': 'Emergency', 'type': 'critique'}

# %%
# Recommendations basées sur les alertes

alertes_occupation = [a for a in alertes if "occupation" in a['titre'].lower()]
alertes_occupation
if alertes_occupation:
  depts_concernes = [a['departement'] for a in alertes_occupation]
  recommendations.append({
    'titre': "Optimisation de la capacité d'accueil",
    'message': f"Envisager d'augmenter la capacité en lits dans les départements suivants : {', '.join(depts_concernes)}. Alternativement, mettre en place un système de transfert vers d'autres établissements pour les cas non urgents."
    })
  print(recommendations)
# Out:
# [{'titre': "Optimisation de la capacité d'accueil", 'message': "Envisager d'augmenter la capacité en lits dans les départements suivants : Neurology, Emergency. Alternativement, mettre en place un système de transfert vers d'autres établissements pour les cas non urgents."}]

# %%
alertes_retablissement = [a for a in alertes if "rétablissement" in a['titre'].lower()]

alertes_retablissement
# Out:
# []

# %%
# Recommandations pour l'amélioration des taux de rétablissement

alertes_retablissement = [a for a in alertes if "rétablissement" in a['titre'].lower()]
if alertes_retablissement:
  depts_concernes = [a['departement'] for a in alertes_retablissement]
  recommendations.append({
  'titre': "Amélioration des taux de rétablissement",
  'message': f"Analyser les protocoles de traitement dans les départements suivants : {', '.join(depts_concernes)}. Envisager une révision des protocoles de soins et une formation supplémentaire du personnel."
  })
  # print(recommendations)

# %%
# Recommandations pour l'optimisation du personnel

alertes_personnel = [a for a in alertes if "médecins" in a['titre'].lower() or "personnel" in a['titre'].lower()]
if alertes_personnel:
  depts_concernes = [a['departement'] for a in alertes_personnel]
  recommendations.append({
      'titre': "Optimisation des ressources humaines",
      'message': f"Recruter du personnel supplémentaire ou réaffecter temporairement du personnel vers les départements suivants : {', '.join(depts_concernes)}. Envisager également des heures supplémentaires pour le personnel existant."
      })
  # print(recommendations)

# %%
# Recommandations financières

alertes_financieres = [a for a in alertes if "financier" in a['titre'].lower() or "déficit" in a['titre'].lower()]
if alertes_financieres:
  recommendations.append({
      'titre': "Optimisation financière",
      'message': "Revoir la structure des coûts et identifier les postes de dépenses à optimiser. Envisager une révision des tarifs pour certains services spécialisés."
      })

# %%
# Recommandations générales basées sur les données

# Recommandation sur la durée d'hospitalisation
duree_moyenne = patient_data["stayDuration"].mean()
if duree_moyenne > 10:  # Si la durée moyenne est supérieure à 10 jours
  recommendations.append({
  'titre': "Réduction de la durée d'hospitalisation",
  'message': f"La durée moyenne d'hospitalisation est de {duree_moyenne:.1f} jours. Mettre en place des protocoles de sortie anticipée pour les patients stables et développer les soins ambulatoires."
        })

# %%
dept_counts = patient_data['department'].value_counts()


print(f"{dept_counts.idxmax()} : {dept_counts.max()}") # Le departement qui s'affiche le plus
print("-----------------")
print(f"{dept_counts.idxmin()} : {dept_counts.min()} ") # Le departement qui s'affiche le moins
print("-----------------")
print(f"Vérifier si {dept_counts.idxmax()} a 3 fois plus de patients que {dept_counts.idxmin()} : {dept_counts.max() > 3 * dept_counts.min()}")
# Out:
# Surgery : 191
# -----------------
# Cardiology : 151
# -----------------
# Vérifier si Surgery a 3 fois plus de patients que Cardiology : False

# %%
# Recommandation sur l'équilibre des départements

dept_counts = patient_data['department'].value_counts()
if len(dept_counts) > 1:  # S'assurer qu'il y a au moins deux départements
  max_dept = dept_counts.idxmax()
  min_dept = dept_counts.idxmin()
  if dept_counts.max() > 3 * dept_counts.min():  # Si un département a 3 fois plus de patients qu'un autre
    recommendations.append({
    'titre': "Rééquilibrage des ressources entre départements",
    'message': f"Le département {max_dept} traite significativement plus de patients que le département {min_dept}. Envisager une redistribution des ressources et du personnel."
    })

# %%
recommendations
# Out:
# [{'titre': "Optimisation de la capacité d'accueil",
#   'message': "Envisager d'augmenter la capacité en lits dans les départements suivants : Neurology, Emergency. Alternativement, mettre en place un système de transfert vers d'autres établissements pour les cas non urgents."},
#  {'titre': 'Optimisation des ressources humaines',
#   'message': 'Recruter du personnel supplémentaire ou réaffecter temporairement du personnel vers les départements suivants : Surgery, Surgery. Envisager également des heures supplémentaires pour le personnel existant.'},
#  {'titre': "Réduction de la durée d'hospitalisation",
#   'message': "La durée moyenne d'hospitalisation est de 13.7 jours. Mettre en place des protocoles de sortie anticipée pour les patients stables et développer les soins ambulatoires."}]

# %%
reco = pd.DataFrame(recommendations)
reco
# Out:
#                                      titre  \
# 0    Optimisation de la capacité d'accueil
# 1     Optimisation des ressources humaines
# 2  Réduction de la durée d'hospitalisation
#
#                                              message
# 0  Envisager d'augmenter la capacité en lits dans...
# 1  Recruter du personnel supplémentaire ou réaffe...
# 2  La durée moyenne d'hospitalisation est de 13.7...

# %% [markdown]
# ## **Résumé**

# %%
# Resume

resume = []

# %%
# Statistiques générales

total_patients = len(patient_data)
patients_hospitalises = len(patient_data[patient_data['isAdmitted']])
taux_occupation_moyen = department_data['bedUtilization'].mean()
taux_retablissement_moyen = department_data['recoveryRate'].mean()

resume.append({
    'titre': "Vue d'ensemble",
    'message': f"L'établissement a traité {total_patients} patients, dont {patients_hospitalises} sont actuellement hospitalisés. Le taux d'occupation moyen est de {taux_occupation_moyen*100:.1f}% et le taux de rétablissement moyen est de {taux_retablissement_moyen*100:.1f}%."
    })
# resume

# %%
# Département le plus performant

if not department_data.empty:
  dept_performance = department_data.copy()
  dept_performance['score'] = dept_performance['recoveryRate'] * 0.6 + (1 - dept_performance['bedUtilization']) * 0.4
  meilleur_dept = dept_performance.loc[dept_performance['score'].idxmax()]

  resume.append({
      'titre': "Département le plus performant",
      'message': f"Le département de {meilleur_dept['department']} présente les meilleurs indicateurs avec un taux de rétablissement de {meilleur_dept['recoveryRate']*100:.1f}% et un taux d'occupation équilibré de {meilleur_dept['bedUtilization']*100:.1f}%."
      })

# %% [markdown]
# - dept_performance['recoveryRate'] * 0.6
#
# → on donne un poids de 60% au taux de guérison (recoveryRate).
#
# - (1 - dept_performance['bedUtilization']) * 0.4
#
# → on donne un poids de 40% à l'inverse du taux d’occupation des lits :
#
# - Plus un lit est libre (i.e. faible taux d’occupation), plus le score augmente ici.

# %%
dept_performance['score']
# Out:
# 0    0.640
# 1    0.536
# 2    0.690
# 3    0.564
# 4    0.450
# 5    0.578
# Name: score, dtype: float64

# %%
resume[1]
# Out:
# {'titre': 'Département le plus performant',
#  'message': "Le département de Oncology présente les meilleurs indicateurs avec un taux de rétablissement de 85.0% et un taux d'occupation équilibré de 55.0%."}

# %%
# Tendances financières

if len(metrics_data) >= 30:
  dernier_mois = metrics_data.sort_values('date').tail(30)
  revenus_total = dernier_mois['revenue'].sum()
  depenses_total = dernier_mois['expenses'].sum()
  profit = revenus_total - depenses_total

  resume.append({
    'titre': "Situation financière",
    'message': f"Sur les 30 derniers jours, l'établissement a généré {revenus_total} de revenus pour {depenses_total} de dépenses, résultant en {'un profit' if profit >= 0 else 'une perte'} de {abs(profit)}."
    })

# %%
abs(profit)
# Out:
# np.int64(554332)

# %%
resume[2]
# Out:
# {'titre': 'Situation financière',
#  'message': "Sur les 30 derniers jours, l'établissement a généré 2856472 de revenus pour 2302140 de dépenses, résultant en un profit de 554332."}

# %%
# Résumé des alertes

if alertes:
  alertes_critiques = len([a for a in alertes if a['type'] == 'critique'])
  alertes_avertissement = len([a for a in alertes if a['type'] == 'avertissement'])

  resume.append({
    'titre': "Points d'attention",
    'message': f"Le système a identifié {alertes_critiques} alertes critiques et {alertes_avertissement} avertissements qui nécessitent une attention particulière."
    })

# %%
resume[3]
# Out:
# {'titre': "Points d'attention",
#  'message': 'Le système a identifié 4 alertes critiques et 3 avertissements qui nécessitent une attention particulière.'}

# %% [markdown]
# # **Tableau Compact : Analysis**

# %%
if len(metrics_data) > 0:
        fig = px.line(metrics_data, x='date', y=['newAdmissions', 'discharges'],
                     title="Admissions_discharges",
                     labels={'value': "count", 'date': "date", 'variable': "metric"},
                     color_discrete_map={'nouvellesAdmissions': "#3498DB", 'sorties': "#1F618D"})
        fig.update_layout(
            height=250,
            legend_title_text='',
            legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1),
            plot_bgcolor= "#141E2E",
            paper_bgcolor= "#141E2E",
            font=dict(color="#E0E0E0"),
            #xaxis=dict(gridcolor= "#E0E0E0"),
            #yaxis=dict(gridcolor=current_theme["border_color"]),
            margin=dict(l=10, r=10, t=40, b=10)
        )
        fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="
2026-02-17","2026-02-18","2026-02-19","2026-02-20","2026-02-21","2026-02-22","2026-02-23","2026-02-24","2026-02-25","2026-02-26","2026-02-27","2026-02-28","2026-03-01","2026-03-02","2026-03-03","2026-03-04","2026-03-05","2026-03-06","2026-03-07","2026-03-08","2026-03-09","2026-03-10","2026-03-11","2026-03-12","2026-03-13","2026-03-14","2026-03-15"],"xaxis":"x","y":[12,17,14,16,11,8,11,20,15,20,15,18,6,8,17,15,7,16,19,14,9,5,17,6,14,10,12,7,8,19,10,7,11,5,16,15,18,8,20,10,7,8,5,6,15,20,14,16,19,7,5,10,6,12,13,15,9,6,8,7,15,12,19,10,13,1 ...

# %%
if not department_data.empty:
        fig = px.bar(department_data, x='department', y='bedUtilization',
                    title="Bed_utilization",
                    labels={'bedUtilization': "Bed_utilization_label", 'department': "department_label"},
                    #color='departement  'departement': t("department_label")},
                    color='department',
                    color_discrete_map={dept: color for dept, color in zip(department_data['department'], ["#3498DB", "#2980B9", "#1F618D", "#2C3E50", "#5DADE2", "#85C1E9", "#7F8C8D"])})
        fig.update_layout(
            height=250,
            coloraxis_showscale=False,
            plot_bgcolor="#141E2E",
            paper_bgcolor="#141E2E",
            font=dict(color="#E0E0E0"),
            #xaxis=dict(gridcolor=current_theme["border_color"]),
            #yaxis=dict(gridcolor=current_theme["border_color"]),
            showlegend=False,
            margin=dict(l=10, r=10, t=40, b=10)
        )
        fig.update_yaxes(range=[0, 1], tickformat='.0%')
        fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="44387913-2b77-47f1-aa7e-aa8d7ed22574" class="plotly-graph-div" style="height:250px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44387913-2b77-47f1-aa7e-aa8d7ed22574")) {                    Plotly.newPlot(                        "44387913-2b77-47f1-aa7e-aa8d7ed22574",                        [{"alignmentgroup":"True","hovertemplate":"department_label=%{x}\u003cbr\u003eBed_utilization_label=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cardiology","marker":{"color":"#3498DB","pattern":{"shape":""}},"name":"Cardiology","offsetgroup":"Cardiology","orientation":"v","showlegend":true,"textposition":"auto","x":["Cardiology"],"xaxis":"x","y":[0.72],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department_label=%{x}\u003cbr\u003eBed_utilization_label=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Neurology","marker":{"color":"#2980B9","pattern":{"shape":""}},"name":"Neurology","offsetgroup":"Neurology","orientation":"v","showlegend":true,"textposition":"auto","x":["Neurology"],"xaxis":"x","y":[0.95],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department_label=%{x}\u003cbr\u003eBed_utilization_label=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Oncology","marker":{"color":"#1F618D","pattern":{"shape":""}},"name":"Oncology","offsetgroup":"Oncology","orientation":"v","showlegend":true,"textposition":"auto","x":["Oncology"],"xaxis":"x","y":[0.55],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department_label=%{x}\u003cbr\u003eBed_utilization_label=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pediatrics","marker":{"color":"#2C3E50","pattern":{"shape":""}},"name":"Pediatrics","offsetgroup":"Pediatrics","orientation":"v","showlegend":true,"textposition":"auto","x":["Pediatrics"],"xaxis":"x","y":[0.82],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department_label=%{x}\u003cbr\u003eBed_utilization_label=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Emergency","marker":{"color":"#5DADE2","pattern":{"shape":""}},"name":"Emergency","offsetgroup":"Emergency","orientation":"v","showlegend":true,"textposition":"auto","x":["Emergency"],"xaxis":"x","y":[1.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"department_label=%{x}\u003cbr\u003eBed_utilization_label=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Surgery","marker":{"color":"#85C1E9","pattern":{"shape":""}},"name":"Surgery","offsetgroup":"Surgery","orientation":"v","showlegend":true,"textposition":"auto","x":["Surgery"],"xaxis":"x","y":[0.83],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0 ...

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Two subplots to compare Recovery Rate and BedUtilization

if not department_data.empty:
  fig = make_subplots(rows=1, cols=2,
                      subplot_titles=("Recovery Rate", "Bed Utilization"))

  # Define the grayscale color sequence
  grayscale_colors = ["#E74C3C", "#C0392B", "#D35400", "#E67E22", "#F39C12", "#922B21", "#7F8C8D"]

  # Add Recovery Rate bar chart
  fig.add_trace(
      go.Bar(x=department_data['department'], y=department_data['recoveryRate'], name='Recovery Rate',
             marker_color=grayscale_colors[:len(department_data['department'])]), # Assign colors
      row=1, col=1
  )

  # Add Bed Utilization bar chart
  fig.add_trace(
      go.Bar(x=department_data['department'], y=department_data['bedUtilization'], name='Bed Utilization',
             marker_color=grayscale_colors[:len(department_data['department'])]), # Assign colors
      row=1, col=2
  )

  # Update layout
  fig.update_layout(
      title_text="Department Performance: Recovery Rate vs. Bed Utilization",
      showlegend=True,
      paper_bgcolor='black',
      plot_bgcolor='black',
      font=dict(color='white')
  )

  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e0cb7b7a-9950-4cae-a541-01330975cf1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0cb7b7a-9950-4cae-a541-01330975cf1b")) {                    Plotly.newPlot(                        "e0cb7b7a-9950-4cae-a541-01330975cf1b",                        [{"marker":{"color":["#E74C3C","#C0392B","#D35400","#E67E22","#F39C12","#922B21"]},"name":"Recovery Rate","x":["Cardiology","Neurology","Oncology","Pediatrics","Emergency","Surgery"],"y":[0.88,0.86,0.85,0.82,0.75,0.85],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":["#E74C3C","#C0392B","#D35400","#E67E22","#F39C12","#922B21"]},"name":"Bed Utilization","x":["Cardiology","Neurology","Oncology","Pediatrics","Emergency","Surgery"],"y":[0.72,0.95,0.55,0.82,1.0,0.83],"type":"bar","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fil ...

# %%
if not patient_data.empty:
  dept_counts = patient_data['department'].value_counts().reset_index()
  dept_counts.columns = [("department_label"), "count"]

  # Créer une carte de couleurs pour les départements
  dept_color_map = {dept: color for dept, color in zip(dept_counts["department_label"], ["#E74C3C", "#C0392B", "#D35400", "#E67E22", "#F39C12", "#922B21", "#7F8C8D"])}

  fig = px.pie(dept_counts, values="count", names="department_label",
    title="patient_distribution",
    color="department_label",
    color_discrete_map=dept_color_map)
  fig.update_traces(textposition='inside', textinfo='percent+label', textfont=dict(color='#000000'))
  fig.update_layout(
    legend=dict(orientation="h", yanchor="bottom", y=-0.1, xanchor="center", x=0.5),
    font=dict(color="#F0F0F0"),
    paper_bgcolor="#0E0808",
    plot_bgcolor="#0E0808"
    )

  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="04598786-c8da-4e97-a9c2-bc039f001181" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04598786-c8da-4e97-a9c2-bc039f001181")) {                    Plotly.newPlot(                        "04598786-c8da-4e97-a9c2-bc039f001181",                        [{"customdata":[["Surgery"],["Neurology"],["Pediatrics"],["Oncology"],["Emergency"],["Cardiology"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"department_label=%{customdata[0]}\u003cbr\u003ecount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Surgery","Neurology","Pediatrics","Oncology","Emergency","Cardiology"],"legendgroup":"","marker":{"colors":["#E74C3C","#C0392B","#D35400","#E67E22","#F39C12","#922B21"]},"name":"","showlegend":true,"values":[191,172,170,160,156,151],"type":"pie","textfont":{"color":"#000000"},"textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{ ...

# %% [markdown]
# ##### **Date Format**

# %%
min_date = metrics_data['date'].min() # .date()
max_date = metrics_data['date'].max() # .date()
plage_date = (min_date, max_date)
plage_date
min_date = pd.to_datetime(min_date)
max_date = pd.to_datetime(max_date)
# min_date = pd.DataFrame(metrics_data['date']).strptime('%Y-M-d')

# %%
if len(plage_date) == 2:
    date_debut, date_fin = plage_date
    # Convertir en datetime pour une comparaison correcte
    date_debut_dt = pd.Timestamp(date_debut)
    date_fin_dt = pd.Timestamp(date_fin)
    quotidien_filtre = metrics_data[(metrics_data['date'] >= date_debut) & (metrics_data['date'] <= date_fin)]
else:
    quotidien_filtre = metrics_data
    # Par défaut à la plage complète si plage_date n'est pas correctement définie
    date_debut = min_date
    date_fin = max_date

# %%
# Display informations

print(f"Date de début : {date_debut}")
print(f"Date de fin : {date_fin}")
print(f"Quantité de données : {len(quotidien_filtre)}")
# Out:
# Date de début : 2025-12-16
# Date de fin : 2026-03-15
# Quantité de données : 90

# %%
# Test Plage date using timedelta between the choosen date and the moment the program is executed

choosen_date = input("Enter the date - yyyy/mm/dd : ")

# Convert choosen date
choosen_date = pd.to_datetime(choosen_date)
print(f"Choosen date : {choosen_date}")
print(f"Moment de l'exécution du programme : {pd.Timestamp.now()}")
print(choosen_date in plage_date)
if choosen_date in plage_date :
  if len(plage_date) == 2:
      date_debut, date_fin = plage_date

  print(plage_date)
  print(f"La différence entre la date de debut et de fin {date_fin - date_debut}")
# Out:
# Enter the date - yyyy/mm/dd : 2026-01-19
# Choosen date : 2026-01-19 00:00:00
# Moment de l'exécution du programme : 2026-03-16 11:53:12.635549
# False

# %%
# Test 2025-04-22

# Test Plage date using timedelta between the choosen date and the moment the program is executed

choosen_date = input("Enter the date - yyyy/mm/dd : ")
print("============================")

# Convert choosen date
choosen_date = pd.to_datetime(choosen_date)
current_date = pd.Timestamp.now()
choosen_date, current_date = plage_date

print(f"Choosen date : {choosen_date}")
print(f"Current date : {pd.Timestamp.now()}")

print(f"Verify if choosen_date in Date column : {choosen_date in quotidien_filtre['date']}")
# print(current_date - choosen_date)
# Out:
# Enter the date - yyyy/mm/dd : 2026-01-19
# ============================
# Choosen date : 2025-12-16
# Current date : 2026-03-16 11:53:15.536164
# Verify if choosen_date in Date column : False

# %%
# Iterate through the date column and calculate the difference between the previous date and the following one in a new column
for index, row in quotidien_filtre.iterrows():
    if index > 0:
        previous_date = quotidien_filtre.loc[index - 1, 'date']
        # quotidien_filtre.loc[index, 'date_diff'] = row['date'] - previous_date

# quotidien_filtre["date_diff"] = pd.to_timedelta(quotidien_filtre["date_diff"])

# %%
# quotidien_filtre

# %%
# Revenue vs Charges

fig = px.line(quotidien_filtre, x='date', y=['revenue', 'expenses'],
  title="Revenue & Expenses",
  labels={'value': "amount", 'date': "date", 'variable': "metric"},
  color_discrete_map={'revenus': "#27AE60", 'depenses': "#C0392B"})

# Ajouter la zone de profit

quotidien_filtre['profit'] = quotidien_filtre['revenue'] - quotidien_filtre['expenses']
fig.add_trace(go.Scatter(
x=quotidien_filtre['date'],
y=quotidien_filtre['profit'],
fill='tozeroy',
mode='none',
name="profit",
fillcolor=f'rgba({int("#27AE60"[1:3], 16)}, {int("#C0392B"[3:5], 16)}, {int("#27AE60"[5:7], 16)}, 0.2)'
        ))

fig.update_layout(
            legend_title_text='',
            legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1),
            plot_bgcolor="#162727",
            paper_bgcolor="#162727",
            font=dict(color="#E0E0E0"),
            xaxis=dict(gridcolor="#1E3535"),
            yaxis=dict(gridcolor="#1E3535")
        )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="85e81526-fa99-47c4-b52f-e7cbc5403541" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("85e81526-fa99-47c4-b52f-e7cbc5403541")) {                    Plotly.newPlot(                        "85e81526-fa99-47c4-b52f-e7cbc5403541",                        [{"hovertemplate":"metric=revenue\u003cbr\u003edate=%{x}\u003cbr\u003eamount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"revenue","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"revenue","orientation":"v","showlegend":true,"x":["2025-12-16","2025-12-17","2025-12-18","2025-12-19","2025-12-20","2025-12-21","2025-12-22","2025-12-23","2025-12-24","2025-12-25","2025-12-26","2025-12-27","2025-12-28","2025-12-29","2025-12-30","2025-12-31","2026-01-01","2026-01-02","2026-01-03","2026-01-04","2026-01-05","2026-01-06","2026-01-07","2026-01-08","2026-01-09","2026-01-10","2026-01-11","2026-01-12","2026-01-13","2026-01-14","2026-01-15","2026-01-16","2026-01-17","2026-01-18","2026-01-19","2026-01-20","2026-01-21","2026-01-22","2026-01-23","2026-01-24","2026-01-25","2026-01-26","2026-01-27","2026-01-28","2026-01-29","2026-01-30","2026-01-31","2026-02-01","2026-02-02","2026-02-03","2026-02-04","2026-02-05","2026-02-06","2026-02-07","2026-02-08","2026-02-09","2026-02-10","2026-02-11","2026-02-12","2026-02-13","2026-02-14","2026-02-15","2026-02-16","2026-02-17","2026-02-18","2026-02-19","2026-02-20","2026-02-21","2026-02-22","2026-02-23","2026-02-24","2026-02-25","2026-02-26","2026-02-27","2026-02-28","2026-03-01","2026-03-02","2026-03-03","2026-03-04","2026-03-05","2026-03-06","2026-03-07","2026-03-08","2026-03-09","2026-03-10","2026-03-11","2026-03-12","2026-03-13","2026-03-14","2026-03-15"],"xaxis":"x","y":[67703,63411,108100,58816,60234,149902,75983,55849,65298,91829,119585,56941,144911,88009,75035,96699,57401,127770,111851,140820,69419,138461,60649,82200,110959,79457,81804,67175,142773,53435,68773,91928,133167,130841,129969,59003,126199,53848,143914,61014,59581,56133,133029,71109,61051,111437,119841,122908,84591,148611,98909,58033,93610,145026,84271,74865,83591,85771,131376,95318,145862,95403,120375,101324,71534,59658,112383,144128,135936,116859,105291,68071,110997,92159,65034,56176,113382,67951,68265,50180,127928,126053,130120,76602,123264,68742,51478,94643,97998,58676],"yaxis":"y","type":"scatter"},{"hovertemplate":"metric=expenses\u003cbr\u003edate=%{x}\u003cbr\u003eamount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"expenses","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"expenses","orientation":"v","showlegend":true,"x":["2025-12-16","2025-12-17","2025-12-18","2025-12-19","2025-12-20","2025-12-21","2025-12-22","2025-12-23","2025-12-24","2025-12-25","2025-12-26","2025-12-27","2025-12-28","2025-12-29","2025-12-30","2025-12-31","2026-01-01","2026-01-02","2026-01-03","2026-01-04","2026-01-05","2026-01-06","2026-01-07","2026-01-08","2026-01-09","2026-01-10","2026-01-11","2026-01-12","2026-01-13","2026-01-14","2026-01-15","2026-01-16","2026-01-17","2026-01-18","2026-01-19","2026-01-20","2026-01-21","2026-01-22","2026-01-23","2026-01-24","2026-01-25","2026-01-26","2026-01-27","2026-01-28","2026-01-29","2026-01-30","2026-01-31","2026-02-01","2026-02-02","2026-02-03","2026-02-04","2026-02-05","2026-02-06","2026-02-07","2026-02-08","2026-02-09","2026-02-10","2026-02-11","2026-02-12","2026-02-13","2026-02-14","2026-02-15","2026-02-16","2026-02-17","2026-02-18","2026-02-19","2026-02-20","2026-02-21","2026-02-22","2026-02-23","2026-02-24","2026-02-25","2026-02-26","2026-02-27","2026-02-28","2026-03-01","2026-03-02","2026-03-03","2026-03-04","2026-03-05","2026-03-06","2026 ...

# %%
# Revenus et coûts par département

if not department_data.empty:
  fig = go.Figure()

fig.add_trace(go.Bar(
  x=department_data['department'],
  y=department_data['totalRevenue'],
  name="revenue",
  marker_color="#4CAF50"
  ))

fig.add_trace(go.Bar(
  x=department_data['department'],
  y=department_data['operatingCost'],
  name="operating_cost",
  marker_color="#B71C1C"
  ))

fig.update_layout(
  title="department_revenue_cost",
  barmode='group',
  xaxis_title="department_label",
  yaxis_title="amount",
  legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1),
  plot_bgcolor="#1E1E1E",
  paper_bgcolor="#1E1E1E",
  font=dict(color="#E0E0E0"),
  xaxis=dict(gridcolor="#2A2A2A"),
  yaxis=dict(gridcolor="#2A2A2A")
            )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8ed55c5f-519b-484f-96fa-9dc9946c03cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ed55c5f-519b-484f-96fa-9dc9946c03cd")) {                    Plotly.newPlot(                        "8ed55c5f-519b-484f-96fa-9dc9946c03cd",                        [{"marker":{"color":"#4CAF50"},"name":"revenue","x":["Cardiology","Neurology","Oncology","Pediatrics","Emergency","Surgery"],"y":[7493272,8622894,9352024,6866343,8242040,14540510],"type":"bar"},{"marker":{"color":"#B71C1C"},"name":"operating_cost","x":["Cardiology","Neurology","Oncology","Pediatrics","Emergency","Surgery"],"y":[3162214,2842455,3143117,2876917,2163947,3369961],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlin ...

# %%
chart_colors =  ["#D4AF37", "#C0C0C0", "#9D8221", "#B8860B", "#E6BE8A", "#DAA520", "#A8A8A8"]

# Section du personnel

# Distribution du personnel par rôle
if not staff_data.empty:
  role_counts = staff_data['role'].value_counts().reset_index()
  role_counts.columns = ["role", "count"]

# Créer une carte de couleurs pour les rôles
  role_colors = {
  "doctor": chart_colors[0],
  "nurse": chart_colors[1],
  "technician": chart_colors[2],
  "administrative": chart_colors[3],
  "support": chart_colors[4]
            }

fig = px.bar(role_counts, x="role", y="count",
  title="staff_distribution",
    color="role",
    color_discrete_map=role_colors)

fig.update_layout(
  showlegend=False,
  plot_bgcolor="#1A1010",
  paper_bgcolor="#1A1010",
  font=dict(color="#F0F0F0"),
  xaxis=dict(gridcolor="#2A1515"),
  yaxis=dict(gridcolor="#2A1515")
  )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bccaaa2f-3471-486c-86cd-b965707baae6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bccaaa2f-3471-486c-86cd-b965707baae6")) {                    Plotly.newPlot(                        "bccaaa2f-3471-486c-86cd-b965707baae6",                        [{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Administrative","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Administrative","offsetgroup":"Administrative","orientation":"v","showlegend":true,"textposition":"auto","x":["Administrative"],"xaxis":"x","y":[51],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Doctor","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Doctor","offsetgroup":"Doctor","orientation":"v","showlegend":true,"textposition":"auto","x":["Doctor"],"xaxis":"x","y":[46],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Technician","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Technician","offsetgroup":"Technician","orientation":"v","showlegend":true,"textposition":"auto","x":["Technician"],"xaxis":"x","y":[37],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nurse","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Nurse","offsetgroup":"Nurse","orientation":"v","showlegend":true,"textposition":"auto","x":["Nurse"],"xaxis":"x","y":[34],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Support","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Support","offsetgroup":"Support","orientation":"v","showlegend":true,"textposition":"auto","x":["Support"],"xaxis":"x","y":[31],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contou ...

# %%
# Performance du personnel

if not staff_data.empty:
  performance_data = staff_data.groupby('role')['performanceScore'].mean().reset_index()

fig = px.bar(performance_data, x='role', y='performanceScore',
  title="performance_score",
  labels={'scorePerformance': "performance_score", 'role': "role"},
  color='role',
  color_discrete_map=role_colors)

fig.update_layout(
  showlegend=False,
  plot_bgcolor="#1A1010",
  paper_bgcolor="#1A1010",
  font=dict(color="#F0F0F0"),
  xaxis=dict(gridcolor="#2A1515"),
  yaxis=dict(gridcolor="#2A1515")
  )

fig.update_yaxes(range=[0, 1])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="06f564d8-fd89-4caf-a254-3ec1361a4976" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06f564d8-fd89-4caf-a254-3ec1361a4976")) {                    Plotly.newPlot(                        "06f564d8-fd89-4caf-a254-3ec1361a4976",                        [{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003eperformanceScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Administrative","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Administrative","offsetgroup":"Administrative","orientation":"v","showlegend":true,"textposition":"auto","x":["Administrative"],"xaxis":"x","y":[0.8543137254901961],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003eperformanceScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Doctor","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Doctor","offsetgroup":"Doctor","orientation":"v","showlegend":true,"textposition":"auto","x":["Doctor"],"xaxis":"x","y":[0.8573913043478261],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003eperformanceScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nurse","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Nurse","offsetgroup":"Nurse","orientation":"v","showlegend":true,"textposition":"auto","x":["Nurse"],"xaxis":"x","y":[0.8532352941176471],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003eperformanceScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Support","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Support","offsetgroup":"Support","orientation":"v","showlegend":true,"textposition":"auto","x":["Support"],"xaxis":"x","y":[0.8661290322580646],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"role=%{x}\u003cbr\u003eperformanceScore=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Technician","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Technician","offsetgroup":"Technician","orientation":"v","showlegend":true,"textposition":"auto","x":["Technician"],"xaxis":"x","y":[0.8675675675675676],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555555555 ...
